# %% [markdown]
# # Glucose Level Forecasting: Advanced Data Analysis and Patient Profiling
#
# ---
#
# ## About the Dataset
#
# This dataset contains comprehensive records of blood glucose readings collected from multiple patients, along with demographic, clinical, and lifestyle information. Each row represents a single glucose measurement tied to a specific patient and time point.
#
# **Key features include:**
# - **id**: Unique identifier for each patient
# - **gl**: Blood glucose reading (target variable)
# - **time**: Timestamp of the glucose measurement
# - **Demographics**: Gender, race, education level, income, marital status
# - **Clinical history**: Diagnosed conditions (hypertension, diabetes duration, comorbidities)
# - **Lifestyle**: Exercise, alcohol use, dietary supplements
# - **Medications**: Binary flags for common prescriptions
#
# **Purpose of Analysis:**
# - Explore patient-wise glucose patterns
# - Conduct advanced statistical and visual analyses
# - Generate actionable insights for glucose forecasting and diabetes management
#
# ---

# %%
# !pip install scikit-learn matplotlib pandas tensorflow --quiet
# Out:
# WARNING: Ignoring invalid distribution ~orch (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~orch (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~orch (/opt/anaconda3/lib/python3.12/site-packages)
#
# [notice] A new release of pip is available: 25.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
pip install upsetplot
# Out:
# WARNING: Ignoring invalid distribution ~orch (/opt/anaconda3/lib/python3.12/site-packages)
# ...
# WARNING: Ignoring invalid distribution ~orch (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~orch (/opt/anaconda3/lib/python3.12/site-packages)
#
# [notice] A new release of pip is available: 25.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install prophet
# Out:
# WARNING: Ignoring invalid distribution ~orch (/opt/anaconda3/lib/python3.12/site-packages)
# ...
# WARNING: Ignoring invalid distribution ~orch (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~orch (/opt/anaconda3/lib/python3.12/site-packages)
#
# [notice] A new release of pip is available: 25.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
pip install joypy
# Out:
# WARNING: Ignoring invalid distribution ~orch (/opt/anaconda3/lib/python3.12/site-packages)
# ...
# WARNING: Ignoring invalid distribution ~orch (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~orch (/opt/anaconda3/lib/python3.12/site-packages)
#
# [notice] A new release of pip is available: 25.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##  Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os, random, itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping



from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
r2_score, mean_squared_error, mean_absolute_error,
confusion_matrix, precision_score, recall_score, f1_score, accuracy_score
)


import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Conv1D, Flatten, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## 1. Load the data

# %%
# Load the dataset
df = pd.read_csv("/Users/mine/office/finalyearproject/raw_data/weinstock.csv")


df.head()

df.columns.tolist()
# Out:
# ['id',
#  'gl',
#  'time',
#  'Gender',
#  'Race',
#  'EduLevel',
#  'AnnualInc',
#  'MaritalStatus',
#  'DaysWkEx',
#  'DaysWkDrinkAlc',
#  'DaysMonBingeAlc',
#  'T1DDiagAge',
#  'NumHospDKA',
#  'NumSHSinceT1DDiag',
#  'InsDeliveryMethod',
#  'UnitsInsTotal',
#  'NumMeterCheckDay',
#  'Height',
#  'Weight',
#  'Hypertension',
#  'Hyperlipidemia',
#  'Hypothyroidism',
#  'Depression',
#  'Coronary artery disease',
#  'Diabetic peripheral neuropathy',
#  'Dyslipidemia',
#  'Chronic kidney disease',
#  'Osteoporosis',
#  'Proliferative diabetic retinopathy',
#  'Hypercholesterolemia',
#  'Erectile dysfunction',
#  'Type I diabetes mellitus',
#  'Aspirin',
#  'Simvastatin',
#  'Lisinopril',
#  'Vitamin D',
#  'Multivitamin preparation',
#  'Omeprazole',
#  'atorvastatin',
#  'Synthroid',
#  'vitamin D3']

# %% [markdown]
# ## 🩸 CGM Dataset Quick Overview

# %%
def check_insulin_df(df, head=5):
    """
    Comprehensive summary of clinical/biometric data for insulin forecasting.
    
    Parameters
    ----------
    df : pd.DataFrame
        Input dataframe.
    head : int, default=5
        Number of rows to show from head and tail.
        
    Returns
    -------
    None. Prints info to screen.
    """
    import pandas as pd
    # --- Validation ---
    if not isinstance(df, pd.DataFrame):
        raise TypeError("Input must be a pandas DataFrame")
    if not isinstance(head, int) or head < 1:
        raise ValueError("head must be a positive integer")
    
    def print_section_header(number, title):
        print(f"\n{number} {title}")
        print("━" * 60)

    print("\n🩸 CGM Dataset Quick Overview")
    print("━" * 60)

    # 1. Basic Info
    print_section_header("1️⃣", "Basic Information")
    print(f"Rows: {df.shape[0]:,} | Columns: {df.shape[1]:,}")
    print(f"Target column: 'unitsinstotal'")
    print(f"Timestamp column: 'time'")
    
    # 2. Data Types, Missing, Null
    print_section_header("2️⃣", "Column Types & Null Values")
    dtype_df = pd.DataFrame({
        'Type': df.dtypes,
        'Non-Null': df.count(),
        'Null': df.isnull().sum(),
        'Null %': (df.isnull().sum() / len(df) * 100).round(2).astype(str) + '%'
    }).reset_index().rename(columns={'index': 'Column'})
    print(dtype_df.to_string(index=False))

    # 3. Unique values for categorical features
    categorical_cols = df.select_dtypes(include=['object', 'category']).columns
    if len(categorical_cols) > 0:
        print_section_header("3️⃣", "Categorical Feature Cardinality")
        for col in categorical_cols:
            print(f"- {col}: {df[col].nunique()} unique values | Top: {df[col].unique()[:5]}")
    
    # 4. Head and Tail
    print_section_header("4️⃣", f"First {head} Rows")
    print(df.head(head))
    print_section_header("5️⃣", f"Last {head} Rows")
    print(df.tail(head))
    
    # 5. Numeric Stats
    numeric_cols = df.select_dtypes(include=[int, float]).columns
    if len(numeric_cols) > 0:
        print_section_header("6️⃣", "Numeric Summary (including outlier quantiles)")
        desc = df[numeric_cols].describe([0, .05, .5, .95, .99, 1]).T.round(2)
        desc['count'] = desc['count'].astype(int)
        print(desc)
        print("\nPotential outliers (values at 0.99 or 1.00 quantile) are flagged above.")

    # 6. Memory Usage
    print_section_header("7️⃣", "Memory Usage")
    mem_total = df.memory_usage(deep=True).sum() / 1024**2
    print(f"Total: {mem_total:.2f} MB")
    print("By column (MB):")
    print(df.memory_usage(deep=True).sort_values(ascending=False) / 1024**2)
    print("━" * 60)
    
check_insulin_df(df, head=10)
# Out:
# 🩸 CGM Dataset Quick Overview
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 1️⃣ Basic Information
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Rows: 645,030 | Columns: 41
# Target column: 'unitsinstotal'
# Timestamp column: 'time'
#
# 2️⃣ Column Types & Null Values
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#                             Column    Type  Non-Null  Null Null %
#                                 id   int64    645030     0   0.0%
#                                 gl float64    645030     0   0.0%
#                               time  object    645030     0   0.0%
#                             Gender  object    645030     0   0.0%
#                               Race  object    645030     0   0.0%
#                           EduLevel   int64    645030     0   0.0%
#                          AnnualInc   int64    645030     0   0.0%
#                      MaritalStatus  object    645030     0   0.0%
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 2.1 Data Inspection & Cleanup
#
# - Standardize column names for consistency
# - Identify and handle missing values
# - Correct data types (e.g., convert time to datetime)
# - Remove or flag duplicates
# - Address outliers and erroneous values

# %%
# 1. Standardize column names for consistency
df.columns = [col.strip().lower().replace(' ', '_') for col in df.columns]

# 2. Identify and handle missing values
# Show % missing per column
print("Missing value percentage per column:")
print(df.isnull().mean().sort_values(ascending=False) * 100)

# Example: Drop rows with missing glucose or time (adjust as needed)
df = df.dropna(subset=['gl', 'time'])

# Optionally, fill missing for other columns (customize as needed)
# df['some_column'] = df['some_column'].fillna(df['some_column'].median())

# 3. Correct data types (convert time to datetime)
df['time'] = pd.to_datetime(df['time'], errors='coerce')

# 4. Remove or flag duplicates
before = df.shape[0]
df = df.drop_duplicates()
after = df.shape[0]
print(f"Removed {before - after} duplicate rows.")

# 5. Address outliers and erroneous values in 'gl'
# Example: Remove glucose values outside 1st–99th percentile as outliers
q_low = df['gl'].quantile(0.01)
q_high = df['gl'].quantile(0.99)
df = df[(df['gl'] >= q_low) & (df['gl'] <= q_high)]

print("Data cleaned. Shape after cleaning:", df.shape)
# Out:
# Missing value percentage per column:
# id                                   0.0000
# hypothyroidism                       0.0000
# coronary_artery_disease              0.0000
# diabetic_peripheral_neuropathy       0.0000
# dyslipidemia                         0.0000
# chronic_kidney_disease               0.0000
# osteoporosis                         0.0000
# proliferative_diabetic_retinopathy   0.0000
# hypercholesterolemia                 0.0000
# erectile_dysfunction                 0.0000
# type_i_diabetes_mellitus             0.0000
# aspirin                              0.0000
# simvastatin                          0.0000
# lisinopril                           0.0000
# vitamin_d                            0.0000
# multivitamin_preparation             0.0000
# omeprazole                           0.0000
# atorvastatin                         0.0000
# synthroid                            0.0000
# depression                           0.0000
# ...

# %% [markdown]
# ## 2.2 Variable Type Analysis

# %%
def grab_col_names(dataframe, cat_th=10, car_th=20):
    """
    Returns lists of categorical, numerical, and cardinal categorical variables for clinical/biometric datasets.
    
    Parameters
    ----------
    dataframe : pd.DataFrame
        Input dataset.
    cat_th : int, default=10
        Threshold for numeric-but-categorical detection.
    car_th : int, default=20
        Threshold for cardinality in categorical columns.
        
    Returns
    -------
    cat_cols : list
        Categorical variable names
    num_cols : list
        Numeric variable names
    cat_but_car : list
        Categorical but cardinal variable names
    """
    # 1. Categorical
    cat_cols = [col for col in dataframe.columns if str(dataframe[col].dtypes) in ["category", "object", "bool"]]
    num_but_cat = [col for col in dataframe.columns if dataframe[col].nunique() < cat_th and
                   dataframe[col].dtypes in [int, float]]
    cat_but_car = [col for col in dataframe.columns if dataframe[col].nunique() > car_th and
                   str(dataframe[col].dtypes) in ["category", "object"]]
    cat_cols = cat_cols + num_but_cat
    cat_cols = [col for col in cat_cols if col not in cat_but_car]
    
    # 2. Numeric
    num_cols = [col for col in dataframe.columns if dataframe[col].dtypes in [int, float]]
    num_cols = [col for col in num_cols if col not in cat_cols]

    print("\n📊 Variable Analysis Report")
    print("━" * 50)
    print(f"Observations: {dataframe.shape[0]:,} | Variables: {dataframe.shape[1]}")

    print("\n- Categorical Variables:", len(cat_cols))
    print("- Numeric Variables:", len(num_cols))
    print("- Cardinal Categorical Variables:", len(cat_but_car))
    print("- Numeric but Categorical Variables:", len(num_but_cat))

    if len(cat_cols) > 0:
        print("\nCategorical:")
        for col in cat_cols:
            print(f"  ▫️ {col} ({dataframe[col].nunique()} unique)")
    if len(num_cols) > 0:
        print("\nNumeric:")
        for col in num_cols:
            print(f"  ▫️ {col} ({dataframe[col].nunique()} unique)")
    if len(num_but_cat) > 0:
        print("\nNumeric but Categorical:")
        for col in num_but_cat:
            print(f"  ▫️ {col} ({dataframe[col].nunique()} unique)")
    if len(cat_but_car) > 0:
        print("\nCardinal Categorical:")
        for col in cat_but_car:
            print(f"  ▫️ {col} ({dataframe[col].nunique()} unique)")
    print("━" * 50)
    return cat_cols, num_cols, cat_but_car

cat_cols, num_cols, cat_but_car = grab_col_names(df)
# Out:
# 📊 Variable Analysis Report
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Observations: 645,030 | Variables: 41
#
# - Categorical Variables: 31
# - Numeric Variables: 9
# - Cardinal Categorical Variables: 0
# - Numeric but Categorical Variables: 27
#
# Categorical:
#   ▫️ gender (2 unique)
#   ▫️ race (5 unique)
#   ▫️ maritalstatus (8 unique)
#   ▫️ insdeliverymethod (2 unique)
#   ▫️ annualinc (8 unique)
#   ▫️ dayswkex (8 unique)
#   ▫️ daysmonbingealc (4 unique)
#   ▫️ numhospdka (3 unique)
#   ▫️ numshsincet1ddiag (8 unique)
#   ▫️ hypertension (2 unique)
#   ▫️ hyperlipidemia (2 unique)
#   ▫️ hypothyroidism (2 unique)
#   ▫️ depression (2 unique)
#   ▫️ coronary_artery_disease (2 unique)
#   ▫️ diabetic_peripheral_neuropathy (2 unique)
#   ▫️ dyslipidemia (2 unique)
#   ▫️ chronic_kidney_disease (2 unique)
#   ▫️ osteoporosis (2 unique)
#   ▫️ proliferative_diabetic_retinopathy (2 unique)
#   ▫️ hypercholesterolemia (2 unique)
#   ▫️ erectile_dysfunction (2 unique)
# ...

# %%
df.columns.tolist()
# Out:
# ['id',
#  'gl',
#  'time',
#  'gender',
#  'race',
#  'edulevel',
#  'annualinc',
#  'maritalstatus',
#  'dayswkex',
#  'dayswkdrinkalc',
#  'daysmonbingealc',
#  't1ddiagage',
#  'numhospdka',
#  'numshsincet1ddiag',
#  'insdeliverymethod',
#  'unitsinstotal',
#  'nummetercheckday',
#  'height',
#  'weight',
#  'hypertension',
#  'hyperlipidemia',
#  'hypothyroidism',
#  'depression',
#  'coronary_artery_disease',
#  'diabetic_peripheral_neuropathy',
#  'dyslipidemia',
#  'chronic_kidney_disease',
#  'osteoporosis',
#  'proliferative_diabetic_retinopathy',
#  'hypercholesterolemia',
#  'erectile_dysfunction',
#  'type_i_diabetes_mellitus',
#  'aspirin',
#  'simvastatin',
#  'lisinopril',
#  'vitamin_d',
#  'multivitamin_preparation',
#  'omeprazole',
#  'atorvastatin',
#  'synthroid',
#  'vitamin_d3',
#  'bmi',
#  'halfday',
#  'hour',
#  'dayofweek',
#  'day',
#  'month',
#  'gl_lag1',
#  'gl_lag2']

# %%
def target_summary_with_num(dataframe, target, numerical_cols, is_target_cat=None, max_unique=None):
    """
    Analyzes the relationship between target variable and numerical variables.

    Parameters
    ----------
    dataframe : pandas.DataFrame
        The DataFrame containing the data
    target : str
        Name of the target variable column
    numerical_cols : str or list
        Single column name or list of numerical column names to analyze
    is_target_cat : bool, optional
        If True, target is treated as categorical
        If False, target is treated as numerical
        If None, type is automatically detected (default)
    max_unique : int, optional
        Maximum unique values for target to be considered categorical
    """
    def print_section(title, content=""):
        """Helper function to print formatted sections"""
        print(f"\n{title}")
        print("▰▱" * 25)
        if content:
            print(content)

    def analyze_categorical_target(col):
        """Helper function for categorical target analysis"""
        stats = dataframe.groupby(target)[col].agg(['count', 'mean', 'median', 
                                                   'min', 'max', 'std']).round(2)
        
        # Calculate additional metrics
        stats['ratio'] = (100 * stats['count'] / len(dataframe)).round(2)
        stats['ratio'] = stats['ratio'].astype(str) + '%'
        
        overall_mean = dataframe[col].mean()
        stats['diff_from_mean'] = (100 * (stats['mean'] - overall_mean) / overall_mean).round(2)
        stats['diff_from_mean'] = stats['diff_from_mean'].apply(
            lambda x: f"+{x}%" if x > 0 else f"{x}%")

        print_section(f"📈 Analysis of {col} by {target}")
        
        # Print summary statistics
        print("\n📊 Summary Statistics by Target Class:")
        print(stats.rename(columns={
            'count': 'Count',
            'mean': 'Mean',
            'median': 'Median',
            'min': 'Min',
            'max': 'Max',
            'std': 'Std',
            'ratio': 'Ratio(%)',
            'diff_from_mean': 'Diff from Mean(%)'
        }))

        # Print insights
        print("\n📈 Key Insights:")
        print(f"▫️ Overall Mean: {overall_mean:.2f}")
        print(f"▫️ Class with Highest Mean: {stats['mean'].idxmax()} ({stats['mean'].max():.2f})")
        print(f"▫️ Class with Lowest Mean: {stats['mean'].idxmin()} ({stats['mean'].min():.2f})")
        print(f"▫️ Mean Range: {stats['mean'].max() - stats['mean'].min():.2f}")

    def analyze_numerical_target(col):
        """Helper function for numerical target analysis"""
        print_section(f"📈 Analysis of {col}")
        
        # Calculate statistics
        stats = dataframe[col].agg(['mean', 'std', 'min', 'max']).round(2)
        quartiles = dataframe[col].quantile([0.25, 0.5, 0.75]).round(2)
        
        # Calculate correlation
        correlation = dataframe[[target, col]].corr().iloc[0, 1].round(3)
        
        print("\n📋 Distribution Statistics:")
        print(f"▫️ Mean: {stats['mean']}")
        print(f"▫️ Std: {stats['std']}")
        print(f"▫️ Q1 (25%): {quartiles[0.25]}")
        print(f"▫️ Median: {quartiles[0.5]}")
        print(f"▫️ Q3 (75%): {quartiles[0.75]}")
        print(f"▫️ IQR: {(quartiles[0.75] - quartiles[0.25]):.2f}")
        print(f"▫️ Correlation with target: {correlation}")

    # Input validation and preprocessing
    numerical_cols = [numerical_cols] if isinstance(numerical_cols, str) else numerical_cols

    # Determine if target is categorical
    if is_target_cat is None:
        is_target_categorical = (
            dataframe[target].dtype in ['object', 'category', 'bool'] or
            dataframe[target].nunique() <= (max_unique if max_unique else 2)
        )
    else:
        is_target_categorical = is_target_cat

    # Print main header
    print("\n📊 Target-Based Numerical Analysis Report")
    print("▰" * 70)

    # Print target information
    print_section("📋 Target Variable Information",
                 f"▫️ Variable Type: {'Categorical' if is_target_categorical else 'Numerical'}\n"
                 f"▫️ Unique Values: {dataframe[target].nunique()}")

    # Print target distribution if categorical
    if is_target_categorical:
        target_dist = pd.DataFrame({
            "Count": dataframe[target].value_counts(),
            "Ratio": (100 * dataframe[target].value_counts() / len(dataframe)).round(2)
        })
        target_dist["Ratio"] = target_dist["Ratio"].astype(str) + '%'
        print_section("📊 Target Class Distribution", target_dist.to_string())

    # Analyze each numerical column
    for col in numerical_cols:
        if is_target_categorical:
            analyze_categorical_target(col)
        else:
            analyze_numerical_target(col)

    print("\n" + "▰" * 70)

# %%
df['bmi'] = df['weight'] / (df['height'] / 100) ** 2

# Typically numerical/continuous:
numerical_columns = [
    'id', 'gl', 'dayswkex', 'dayswkdrinkalc', 'daysmonbingealc',
    't1ddiagage', 'numhospdka', 'numshsincet1ddiag', 'annualinc',
    'unitsinstotal', 'nummetercheckday', 'height', 'weight', 'bmi'
]
target_summary_with_num(
    dataframe=df,
    target='gl',
    numerical_cols=numerical_columns,   # <-- Updated list
    is_target_cat=False                 # Because 'unitsinstotal' is continuous
)
# Out:
# 📊 Target-Based Numerical Analysis Report
# ▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰
#
# 📋 Target Variable Information
# ▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱
# ▫️ Variable Type: Numerical
# ▫️ Unique Values: 363
#
# 📈 Analysis of id
# ▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱
#
# 📋 Distribution Statistics:
# ▫️ Mean: 98.92
# ▫️ Std: 58.31
# ▫️ Q1 (25%): 48.0
# ▫️ Median: 98.0
# ▫️ Q3 (75%): 150.0
# ▫️ IQR: 102.00
# ▫️ Correlation with target: 0.022
#
# 📈 Analysis of gl
# ▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱
#
# 📋 Distribution Statistics:
# ▫️ Mean: 174.06
# ▫️ Std: 82.58
# ▫️ Q1 (25%): 112.0
# ▫️ Median: 161.0
# ▫️ Q3 (75%): 223.0
# ▫️ IQR: 111.00
# ▫️ Correlation with target: 1.0
#
# 📈 Analysis of dayswkex
# ▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱
#
# 📋 Distribution Statistics:
# ▫️ Mean: 4.95
# ▫️ Std: 2.08
# ▫️ Q1 (25%): 4.0
# ▫️ Median: 5.0
# ▫️ Q3 (75%): 7.0
# ▫️ IQR: 3.00
# ...

# %% [markdown]
# ### **Correlation Heatmap of Numerical Features**

# %%
# Optionally drop 'id' if not meaningful for correlation
plot_cols = [col for col in numerical_columns if col.lower() != 'id']
corr_matrix = df[plot_cols].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

plt.figure(figsize=(14, 11))
sns.set(style="white", font_scale=1.2)

ax = sns.heatmap(
    corr_matrix,
    mask=mask,
    annot=True,
    fmt=".2f",
    cmap=sns.diverging_palette(220, 20, as_cmap=True),
    linewidths=1.8,
    linecolor='grey',
    square=True,
    cbar_kws={
        "shrink": 0.85,
        'label': '**Correlation Coefficient**',
        'aspect': 25,
        'pad': 0.02
    },
    annot_kws={'size':14, 'weight':'bold', 'color':'black', 'bbox':dict(boxstyle='round,pad=0.35', facecolor='white', edgecolor='0.3', alpha=0.6)}
)

plt.title("**Correlation Heatmap of Numerical Features**", fontsize=26, fontweight='bold', pad=18)
plt.xticks(fontsize=14, fontweight='bold', rotation=35, ha='right')
plt.yticks(fontsize=14, fontweight='bold', rotation=0)
plt.gca().set_facecolor('#F7F7F7')  # Subtle background
plt.tight_layout(pad=3)
plt.show()

# %%
def target_summary_with_num(dataframe, target, numerical_cols, is_target_cat=None, max_unique=None):
    """
    Analyzes the relationship between target variable and numerical variables.

    Parameters
    ----------
    dataframe : pandas.DataFrame
        The DataFrame containing the data
    target : str
        Name of the target variable column
    numerical_cols : str or list
        Single column name or list of numerical column names to analyze
    is_target_cat : bool, optional
        If True, target is treated as categorical
        If False, target is treated as numerical
        If None, type is automatically detected (default)
    max_unique : int, optional
        Maximum unique values for target to be considered categorical
    """
    def print_section(title, content=""):
        """Helper function to print formatted sections"""
        print(f"\n{title}")
        print("▰▱" * 25)
        if content:
            print(content)

    def analyze_categorical_target(col):
        """Helper function for categorical target analysis"""
        stats = dataframe.groupby(target)[col].agg(['count', 'mean', 'median', 
                                                   'min', 'max', 'std']).round(2)
        
        # Calculate additional metrics
        stats['ratio'] = (100 * stats['count'] / len(dataframe)).round(2)
        stats['ratio'] = stats['ratio'].astype(str) + '%'
        
        overall_mean = dataframe[col].mean()
        stats['diff_from_mean'] = (100 * (stats['mean'] - overall_mean) / overall_mean).round(2)
        stats['diff_from_mean'] = stats['diff_from_mean'].apply(
            lambda x: f"+{x}%" if x > 0 else f"{x}%")

        print_section(f"📈 Analysis of {col} by {target}")
        
        # Print summary statistics
        print("\n📊 Summary Statistics by Target Class:")
        print(stats.rename(columns={
            'count': 'Count',
            'mean': 'Mean',
            'median': 'Median',
            'min': 'Min',
            'max': 'Max',
            'std': 'Std',
            'ratio': 'Ratio(%)',
            'diff_from_mean': 'Diff from Mean(%)'
        }))

        # Print insights
        print("\n📈 Key Insights:")
        print(f"▫️ Overall Mean: {overall_mean:.2f}")
        print(f"▫️ Class with Highest Mean: {stats['mean'].idxmax()} ({stats['mean'].max():.2f})")
        print(f"▫️ Class with Lowest Mean: {stats['mean'].idxmin()} ({stats['mean'].min():.2f})")
        print(f"▫️ Mean Range: {stats['mean'].max() - stats['mean'].min():.2f}")

    def analyze_numerical_target(col):
        """Helper function for numerical target analysis"""
        print_section(f"📈 Analysis of {col}")
        
        # Calculate statistics
        stats = dataframe[col].agg(['mean', 'std', 'min', 'max']).round(2)
        quartiles = dataframe[col].quantile([0.25, 0.5, 0.75]).round(2)
        
        # Calculate correlation
        correlation = dataframe[[target, col]].corr().iloc[0, 1].round(3)
        
        print("\n📋 Distribution Statistics:")
        print(f"▫️ Mean: {stats['mean']}")
        print(f"▫️ Std: {stats['std']}")
        print(f"▫️ Q1 (25%): {quartiles[0.25]}")
        print(f"▫️ Median: {quartiles[0.5]}")
        print(f"▫️ Q3 (75%): {quartiles[0.75]}")
        print(f"▫️ IQR: {(quartiles[0.75] - quartiles[0.25]):.2f}")
        print(f"▫️ Correlation with target: {correlation}")

    # Input validation and preprocessing
    numerical_cols = [numerical_cols] if isinstance(numerical_cols, str) else numerical_cols

    # Determine if target is categorical
    if is_target_cat is None:
        is_target_categorical = (
            dataframe[target].dtype in ['object', 'category', 'bool'] or
            dataframe[target].nunique() <= (max_unique if max_unique else 2)
        )
    else:
        is_target_categorical = is_target_cat

    # Print main header
    print("\n📊 Target-Based Numerical Analysis Report")
    print("▰" * 70)

    # Print target information
    print_section("📋 Target Variable Information",
                 f"▫️ Variable Type: {'Categorical' if is_target_categorical else 'Numerical'}\n"
                 f"▫️ Unique Values: {dataframe[target].nunique()}")

    # Print target distribution if categorical
    if is_target_categorical:
        target_dist = pd.DataFrame({
            "Count": dataframe[target].value_counts(),
            "Ratio": (100 * dataframe[target].value_counts() / len(dataframe)).round(2)
        })
        target_dist["Ratio"] = target_dist["Ratio"].astype(str) + '%'
        print_section("📊 Target Class Distribution", target_dist.to_string())

    # Analyze each numerical column
    for col in numerical_cols:
        if is_target_categorical:
            analyze_categorical_target(col)
        else:
            analyze_numerical_target(col)

    print("\n" + "▰" * 70)
    
target_summary_with_num(
    dataframe=df,
    target='gl',
    numerical_cols=numerical_columns,   # <-- Updated list
    is_target_cat=False                 # Because 'unitsinstotal' is continuous
)
# Out:
# 📊 Target-Based Numerical Analysis Report
# ▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰▰
#
# 📋 Target Variable Information
# ▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱
# ▫️ Variable Type: Numerical
# ▫️ Unique Values: 363
#
# 📈 Analysis of id
# ▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱
#
# 📋 Distribution Statistics:
# ▫️ Mean: 97.92
# ▫️ Std: 58.98
# ▫️ Q1 (25%): 45.0
# ▫️ Median: 98.0
# ▫️ Q3 (75%): 150.0
# ▫️ IQR: 105.00
# ▫️ Correlation with target: 0.023
#
# 📈 Analysis of gl
# ▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱
#
# 📋 Distribution Statistics:
# ▫️ Mean: 173.55
# ▫️ Std: 82.7
# ▫️ Q1 (25%): 112.0
# ▫️ Median: 161.0
# ▫️ Q3 (75%): 223.0
# ▫️ IQR: 111.00
# ▫️ Correlation with target: 1.0
#
# 📈 Analysis of dayswkex
# ▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱▰▱
#
# 📋 Distribution Statistics:
# ▫️ Mean: 4.91
# ▫️ Std: 2.11
# ▫️ Q1 (25%): 3.0
# ▫️ Median: 5.0
# ▫️ Q3 (75%): 7.0
# ▫️ IQR: 4.00
# ...

# %% [markdown]
# ### 2.2 Gender Distribution of Patients

# %%
# Robust standardization and clean-up of gender column
df['gender'] = df['gender'].astype(str).str.strip().str.lower()
gender_map = {'male': 'Male', 'm': 'Male', 'female': 'Female', 'f': 'Female'}
df['gender'] = df['gender'].map(gender_map).fillna('Other')

# Only keep known genders
patient_gender = df.drop_duplicates('id')[['id', 'gender']]
gender_counts = patient_gender['gender'].value_counts()
present_labels = gender_counts.index.tolist()
present_values = gender_counts.values

# Set professional colors (use as many as needed)
color_palette = sns.color_palette("Set2", n_colors=len(present_labels))

# Handle the case of missing or all-unknown gender data
if len(present_values) == 0:
    print("No valid gender information found for patients.")
else:
    # Annotate with count and percentage
    def make_autopct(values):
        def my_autopct(pct):
            total = sum(values)
            count = int(round(pct * total / 100.0))
            return '{:.1f}%\n({:d})'.format(pct, count)
        return my_autopct

    # Advanced pie chart
    plt.figure(figsize=(7,7))
    patches, texts, autotexts = plt.pie(
        present_values,
        labels=present_labels,
        colors=color_palette,
        autopct=make_autopct(present_values),
        startangle=90,
        explode=[0.03] * len(present_values),
        shadow=True,
        textprops={'fontsize': 14, 'weight': 'bold'}
    )

    plt.setp(texts, size=16, weight='bold')
    plt.setp(autotexts, size=14, weight='normal', color='white')
    plt.title('Gender Distribution of Unique Patients', fontsize=18, weight='bold', pad=20)
    plt.gca().set_aspect('equal')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### **Patient-Wise Data Aggregation**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

main_color = sns.color_palette("crest", n_colors=15)[8]

plt.figure(figsize=(10, 6))
ax = plt.gca()
ax.set_facecolor('#F9F9F9')

# Histogram and KDE
sns.histplot(
    df['t1ddiagage'],
    bins=15,
    kde=True,
    stat='percent',
    color=main_color,
    edgecolor='white',
    linewidth=1.6,
    alpha=0.94
)

mean_diag = df['t1ddiagage'].mean()
median_diag = df['t1ddiagage'].median()

# Highly contrasting, thick lines
plt.axvline(mean_diag, color='black', linestyle='-', linewidth=3.5, zorder=3)
plt.axvline(median_diag, color='crimson', linestyle='--', linewidth=3.5, zorder=3)

# Annotation for mean
plt.text(
    mean_diag + 0.3, plt.ylim()[1]*0.95, f"Mean: {mean_diag:.1f}",
    color='black', fontsize=14, fontweight='bold', va='top', ha='left',
    bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3', alpha=0.88)
)
# Annotation for median
plt.text(
    median_diag - 0.3, plt.ylim()[1]*0.86, f"Median: {median_diag:.1f}",
    color='crimson', fontsize=14, fontweight='bold', va='top', ha='right',
    bbox=dict(facecolor='white', edgecolor='crimson', boxstyle='round,pad=0.3', alpha=0.88)
)

plt.title("**Age at T1D Diagnosis (%)**", fontsize=21, fontweight='bold', pad=18)
plt.xlabel("**Diagnosis Age (yrs)**", fontsize=16, fontweight='bold', labelpad=10)
plt.ylabel("**Percentage**", fontsize=16, fontweight='bold', labelpad=10)
plt.xticks(fontsize=13, fontweight='bold')
plt.yticks(fontsize=13, fontweight='bold')
plt.grid(axis='y', linestyle=':', alpha=0.32, linewidth=1)
sns.despine()
ax.spines['bottom'].set_linewidth(1.4)
ax.spines['left'].set_linewidth(1.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Glucose Distribution by Gender**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy.stats import skew

# Standardize gender column
df['gender'] = df['gender'].astype(str).str.strip().str.title()

# Prepare stats by gender
stats = df.groupby('gender')['gl'].agg(['mean', 'median', 'var']).reset_index()
stats['skewness'] = df.groupby('gender')['gl'].apply(lambda x: skew(x, nan_policy='omit')).values
stats_display = stats.copy()
stats_display.columns = ['Gender', 'Mean', 'Median', 'Variance', 'Skewness']
stats_display = stats_display.round(2)

# Colors for genders
colors = {'Male': 'blue', 'Female': 'red'}

# ----- Plot KDE -----
fig, ax = plt.subplots(figsize=(10,6))

for gender in stats['gender']:
    subset = df[df['gender'] == gender]['gl'].dropna()
    sns.kdeplot(subset, shade=True, color=colors[gender], label=gender, linewidth=2)
    
    # Mean line (dashed)
    ax.axvline(stats.loc[stats['gender'] == gender, 'mean'].values[0],
               color=colors[gender], linestyle='--', linewidth=2)
    # Median line (dotted)
    ax.axvline(stats.loc[stats['gender'] == gender, 'median'].values[0],
               color=colors[gender], linestyle=':', linewidth=2)

ax.set_xlabel(r'Glucose concentration in blood, $x$', fontsize=14, weight='bold')
ax.set_ylabel('Probability Density', fontsize=14, weight='bold')
ax.set_title('Glucose Distribution by Gender', fontsize=16, weight='bold')
ax.legend(fontsize=12, frameon=True)

plt.tight_layout(rect=[0,0.15,1,1])  # leave space for table

# ----- Add Table Below Plot -----
table = plt.table(
    cellText=stats_display.values,
    colLabels=stats_display.columns,
    cellLoc='center',
    loc='bottom',
    bbox=[0.0, -0.35, 1, 0.25]  # [left, bottom, width, height]
)

# Style the table
table.auto_set_font_size(False)
table.set_fontsize(12)

# Bold headers + cells
for (row, col), cell in table.get_celld().items():
    if row == 0:  # header row
        cell.set_text_props(weight='bold', color='white')
        cell.set_facecolor('black')
    else:
        cell.set_facecolor('#f2f2f2' if row % 2 == 0 else 'white')

plt.show()
# Out:
# /var/folders/wk/6g53_52x66xbm6gmgx0krkb40000gn/T/ipykernel_71860/1547388318.py:24: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#
# /var/folders/wk/6g53_52x66xbm6gmgx0krkb40000gn/T/ipykernel_71860/1547388318.py:24: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.

# %% [markdown]
# Social Lifestyle imapact on Glucose Levels

# %%
# ---------- 1) Map codes → education names ----------
edu_labels = {
    0: "No Qualification",
    1: "Primary School",
    2: "High School",
    3: "Diploma",
    4: "Associate",
    5: "Bachelor",
    6: "Postgrad Diploma",
    7: "Masters",
    8: "Professional",
    9: "Doctorate",
    10: "Other"
}
df['edu_name'] = df['edulevel'].map(edu_labels).fillna("Unknown")

# ---------- 2) Mean glucose per education ----------
edu_glucose = (
    df.groupby('edu_name', as_index=False)['gl']
      .mean()
      .rename(columns={'gl':'mean_glucose'})
)

# ---------- 3) Classify ----------
def classify_glucose(v):
    if v <= 115:  return "Excellent"
    elif v <= 180: return "Good"
    else:          return "Poor"

edu_glucose['Glucose_Status'] = edu_glucose['mean_glucose'].apply(classify_glucose)

# Order categories
status_order = {"Excellent":0, "Good":1, "Poor":2}
edu_glucose['status_order'] = edu_glucose['Glucose_Status'].map(status_order)
edu_glucose = edu_glucose.sort_values(['status_order','mean_glucose']).reset_index(drop=True)

# Colors
color_map = {"Excellent":"#2ca02c", "Good":"#ff7f0e", "Poor":"#d62728"}
edu_glucose['Color'] = edu_glucose['Glucose_Status'].map(color_map)

# ---------- 4) Plot ----------
fig, ax = plt.subplots(figsize=(14,6))
x = range(len(edu_glucose))
bars = ax.bar(x, edu_glucose['mean_glucose'], color=edu_glucose['Color'], edgecolor='black')

# Labels above bars
for xi, val, status in zip(x, edu_glucose['mean_glucose'], edu_glucose['Glucose_Status']):
    ax.text(xi, val + 2, f"{val:.1f}\n{status}", ha='center', va='bottom',
            fontsize=10, fontweight='bold')

# Axes, ticks, title
ax.set_xticks(x)
ax.set_xticklabels(edu_glucose['edu_name'], rotation=30, ha='right', fontsize=12, fontweight='bold')
ax.set_ylabel("Mean Glucose (mg/dL)", fontsize=14, fontweight='bold')
ax.set_xlabel("Education Level", fontsize=14, fontweight='bold')
ax.set_title("Glucose Distribution by Education", fontsize=16, fontweight='bold', pad=35)

# Reference lines
ax.axhline(115, linestyle='--', linewidth=1.2, color='blue')
ax.axhline(180, linestyle='--', linewidth=1.2, color='blue')

# Bold axis spines + ticks
for spine in ['bottom','left','top','right']:
    ax.spines[spine].set_linewidth(1.5)

ax.tick_params(axis='x', labelsize=12, width=1.5, length=5)
ax.tick_params(axis='y', labelsize=12, width=1.5, length=5)

# Bold Legend under title
legend_elements = [
    Patch(facecolor=color_map["Excellent"], label="Excellent (≤115 mg/dL)"),
    Patch(facecolor=color_map["Good"],      label="Good (116–180 mg/dL)"),
    Patch(facecolor=color_map["Poor"],      label="Poor (>180 mg/dL)")
]
leg = ax.legend(handles=legend_elements, fontsize=12, ncol=3,
                loc="upper center", bbox_to_anchor=(0.5, 1.08), frameon=True)

# Make legend text bold
for text in leg.get_texts():
    text.set_fontweight("bold")

plt.tight_layout()
plt.show()

# %%
# ============================================================
# Box Plot: Glucose Distribution by Annual Income (per £1k)
# ============================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ---------- Prep ----------
d = df[['annualinc','gl']].copy()
d['annualinc'] = pd.to_numeric(d['annualinc'], errors='coerce')
d['gl']        = pd.to_numeric(d['gl'], errors='coerce')
d = d.dropna(subset=['annualinc','gl'])
d = d[(d['annualinc'] > 0) & (d['gl'] > 20) & (d['gl'] < 600)].copy()

# Convert to £k if values are raw pounds
p95 = d['annualinc'].quantile(0.95)
d['inc_k'] = d['annualinc'] / 1000.0 if p95 > 1000 else d['annualinc']

# Round to nearest £1k
d['inc_k_1k'] = d['inc_k'].round().astype(int)

# Filter groups with enough patients
counts = d['inc_k_1k'].value_counts()
valid_groups = counts[counts >= 10].index  # require ≥10 samples
d_plot = d[d['inc_k_1k'].isin(valid_groups)].copy()
order = sorted(valid_groups)

# ---------- Plot ----------
sns.set_theme(style="whitegrid")
plt.figure(figsize=(14,6))

ax = sns.boxplot(
    data=d_plot,
    x="inc_k_1k",
    y="gl",
    showfliers=False,
    showmeans=False,
    medianprops={"visible": False},   # hide median line
    whiskerprops={"linewidth": 2},    # thicker whiskers
    boxprops={"linewidth": 2},        # thicker box outline
    capprops={"linewidth": 2},        # thicker caps
    palette="Spectral",
    order=order
)

# Add reference thresholds
ax.axhline(115, linestyle=":", linewidth=2.0, color="black", alpha=0.9, label="Normal upper")
ax.axhline(180, linestyle=":", linewidth=2.0, color="red", alpha=0.9, label="High threshold")

# Titles & labels (all bold)
ax.set_title("Glucose Distribution by Annual Income ", fontsize=16, fontweight="bold", pad=14)
ax.set_xlabel("Annual Income ", fontsize=13, fontweight="bold")
ax.set_ylabel("Glucose (mg/dL)", fontsize=13, fontweight="bold")

# Bold x and y tick values
ax.set_xticklabels([f"{k}k" for k in order], fontsize=11, fontweight="bold", rotation=0, ha="center")
ax.set_yticklabels([f"{int(t)}" for t in ax.get_yticks()], fontsize=11, fontweight="bold")


# Legend
ax.legend(fontsize=11, frameon=True, loc="upper right")

sns.despine()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/wk/6g53_52x66xbm6gmgx0krkb40000gn/T/ipykernel_71860/156481607.py:34: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# /var/folders/wk/6g53_52x66xbm6gmgx0krkb40000gn/T/ipykernel_71860/156481607.py:58: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#
# /var/folders/wk/6g53_52x66xbm6gmgx0krkb40000gn/T/ipykernel_71860/156481607.py:59: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %% [markdown]
# ### 2.14 Glucose Trends by Marital Status (12-Hour Intervals, Risk Zones Highlighted)
#
# This plot shows mean glucose trends by marital status in 12-hour intervals,
# with background shading for clinically relevant glucose risk zones:
# - Normal (70–100 mg/dL)
# - Medium (100–180 mg/dL)
# - High (>180 mg/dL)
#
# ---

# %%
# -------- Prep --------
df = df.copy()
df['time'] = pd.to_datetime(df['time'], errors='coerce')
df = df.dropna(subset=['time','gl'])
df['maritalstatus'] = df['maritalstatus'].astype(str).str.strip().str.title()
df['maritalstatus'] = df['maritalstatus'].replace({'Single (Never Married)': 'Single'})
df['day'] = df['time'].dt.floor('1D')   # DAILY buckets

# Aggregate
agg = (df.groupby(['day','maritalstatus'])['gl']
         .agg(mean='mean', median='median', std='std', count='count')
         .reset_index())
agg['sem']  = agg['std'] / np.sqrt(agg['count'].replace(0, np.nan))
agg['ci95'] = 1.96 * agg['sem']

# Top statuses
top_status = agg['maritalstatus'].value_counts().index[:4].tolist()
agg = agg[agg['maritalstatus'].isin(top_status)].sort_values('day')

# -------- Plot --------
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(22, 12))

# Risk zones with new colors
ymax = max(200, (agg['mean'].max() if not agg.empty else 200)) + 10
zones = [
    (70, 100, '#b3e6b3', 'Normal (70–100)'),    # green
    (100, 180, '#ffe680', 'Medium (100–180)'),  # yellow
    (180, ymax, '#ff9999', 'High (>180)'),      # red
]
for lo, hi, color, lab in zones:
    ax.axhspan(lo, hi, facecolor=color, alpha=0.3, zorder=0, label=lab)

for y in (70, 100, 180):
    ax.axhline(y, linewidth=1, linestyle='--', alpha=0.6, zorder=1)
    ax.text(agg['day'].min() if not agg.empty else 0, y+1, f'{y}',
            va='bottom', ha='left', fontsize=12, fontweight='bold', alpha=0.7)

# Colors for lines
palette = sns.color_palette(n_colors=len(top_status))
color_map = dict(zip(top_status, palette))

# Lines
for status in top_status:
    sub = agg[agg['maritalstatus']==status]
    if sub.empty: continue

    ax.fill_between(sub['day'],
                    (sub['mean']-sub['ci95']).clip(lower=0),
                    sub['mean']+sub['ci95'],
                    alpha=0.16, color=color_map[status], linewidth=0)

    ax.plot(sub['day'], sub['mean'],
            color=color_map[status], marker='o', linewidth=2.8, zorder=4,
            path_effects=[pe.Stroke(linewidth=6, foreground='white', alpha=0.9), pe.Normal()],
            label=status)

    sparse = sub[sub['count']<20]
    if not sparse.empty:
        ax.scatter(sparse['day'], sparse['mean'],
                   s=90, facecolors='none', edgecolors=color_map[status],
                   linewidths=2, zorder=5)

# -------- Labels --------
ax.set_title("Glucose Trends by Marital Status (Daily Buckets)", fontsize=26, fontweight='bold', pad=22)
ax.set_xlabel("Time (Days)", fontsize=18, fontweight='bold', labelpad=15)
ax.set_ylabel("Mean Glucose (mg/dL)", fontsize=18, fontweight='bold', labelpad=15)

# Bold tick labels
ax.tick_params(axis='x', labelsize=13, labelrotation=35)
ax.tick_params(axis='y', labelsize=13)
for tick in ax.get_xticklabels() + ax.get_yticklabels():
    tick.set_fontweight('bold')

# Legend
zone_patches = [Patch(facecolor=c, alpha=0.3, label=lab) for (_,_,c,lab) in zones]
status_lines = [Line2D([0],[0], color=color_map[s], lw=3, label=s) for s in top_status]
hollow = Line2D([0],[0], marker='o', color='gray', lw=0,
                markerfacecolor='none', markersize=9, label='n < 20 in bucket')
leg = ax.legend(handles=zone_patches + status_lines + [hollow],
                title="Zones & Marital Status", bbox_to_anchor=(1.02,1),
                loc='upper left', fontsize=14, title_fontsize=16, frameon=True)
for txt in leg.get_texts():
    txt.set_fontweight('bold')
leg.get_title().set_fontweight('bold')

sns.despine(left=False, bottom=False)

# -------- Summary Table (Bottom) --------
tail = (agg.sort_values(['maritalstatus','day'])
           .groupby('maritalstatus', as_index=False)
           .tail(1)[['maritalstatus','mean','median','count']]
           .rename(columns={'maritalstatus':'Status','mean':'Mean','median':'Median','count':'N'}))
if not tail.empty:
    tail['Mean']   = tail['Mean'].round(1)
    tail['Median'] = tail['Median'].round(1)

    # Place table below plot
    table = plt.table(cellText=tail.values,
                      colLabels=tail.columns,
                      loc='bottom',
                      cellLoc='center',
                      colLoc='center',
                      bbox=[0.15, -0.35, 0.7, 0.25])  # centered under plot

    table.auto_set_font_size(False)
    table.set_fontsize(13)

    # Bold headers + cells
    for (row, col), cell in table.get_celld().items():
        cell.get_text().set_fontweight('bold')
        if row == 0:  # header row
            cell.get_text().set_fontsize(14)

# Adjust for table space
plt.subplots_adjust(bottom=0.3, top=0.88, right=0.75)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.X Distribution of Mean Patient Glucose by Income Bin (Ridgeline Plot)
#
# This ridgeline plot visualizes the distribution of average glucose levels among patients, grouped by income bin.
# Overlapping density curves enable clear comparison of glucose control patterns across socioeconomic strata, highlighting differences in the central tendency and variability between groups.
#
# ---

# %%
# Legend UNDER the title — grouped bars: Exercise vs Drinking

import numpy as np, pandas as pd, matplotlib.pyplot as plt

# assumes df in memory with: id, gl, dayswkex, (dayswkdrinkalc or daysmonbingealc)
cols = {c.lower(): c for c in df.columns}
id_col, gl_col = cols.get("id","id"), cols.get("gl","gl")
ex_col = cols.get("dayswkex","dayswkex")
drink_week_col, binge_month_col = cols.get("dayswkdrinkalc"), cols.get("daysmonbingealc")

if drink_week_col:
    alc_col, drink_source = drink_week_col, "weekly"
elif binge_month_col:
    alc_col, drink_source = binge_month_col, "binge_to_week"
else:
    raise ValueError("Need 'dayswkdrinkalc' or 'daysmonbingealc' in df.")

d = df[[id_col, gl_col, ex_col, alc_col]].copy()
for c in [gl_col, ex_col, alc_col]: d[c] = pd.to_numeric(d[c], errors="coerce")
d = d.dropna().query(f"20 < {gl_col} < 600")

per_pat = (d.groupby(id_col, as_index=False)
             .agg(mean_glucose=(gl_col,"mean"),
                  ex_days=(ex_col,"mean"),
                  alc_days_raw=(alc_col,"mean")))
per_pat["alc_days_week"] = per_pat["alc_days_raw"] if drink_source=="weekly" else per_pat["alc_days_raw"]*(7/30)

per_pat["ex_bin"]  = per_pat["ex_days"].round().clip(0,7).astype(int)
per_pat["alc_bin"] = per_pat["alc_days_week"].round().clip(0,7).astype(int)

def agg_bins(df_, col):
    out = (df_.groupby(col)
             .agg(count=(col,"size"), mean_glucose=("mean_glucose","mean"))
             .reset_index().rename(columns={col:"day"}))
    return pd.DataFrame({"day":np.arange(0,8)}).merge(out, on="day", how="left")

ex_agg, alc_agg = agg_bins(per_pat,"ex_bin"), agg_bins(per_pat,"alc_bin")

plt.rcParams.update({"axes.edgecolor":"#111","axes.linewidth":1.8,"font.size":12})
fig, ax = plt.subplots(figsize=(14,6))
ax.set_facecolor("#fcfcfd")

x = np.arange(8); width = 0.38
b1 = ax.bar(x - width/2, ex_agg["count"].fillna(0), width, color="#2563eb",
            edgecolor="black", linewidth=1.1, label="Exercise (days/week)")
b2 = ax.bar(x + width/2, alc_agg["count"].fillna(0), width, color="#f97316",
            edgecolor="black", linewidth=1.1, label="Drinking (days/week)")

def annotate(bars, means):
    ymax = max(ax.get_ylim()[1], (ex_agg["count"].max() or 1))
    for bar, m in zip(bars, means):
        if pd.notna(m):
            ax.text(bar.get_x()+bar.get_width()/2, bar.get_height()+ymax*0.02,
                    f"µ={m:.1f}", ha="center", va="bottom", fontsize=11, fontweight="bold")
annotate(b1, ex_agg["mean_glucose"].values)
annotate(b2, alc_agg["mean_glucose"].values)

ax.set_xticks(x); ax.set_xticklabels([str(i) for i in x], fontweight="bold")
ax.set_xlabel("Days (0–7)", fontsize=13, fontweight="bold")
ax.set_ylabel("Total count of patients", fontsize=13, fontweight="bold")

# --- Title (suptitle) and legend placed directly beneath it ---
fig.suptitle("Counts by Day Bin: Exercise vs Drinking\n(mean glucose annotated on bars)",
             fontsize=16, fontweight="bold", y=0.98)

handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels,
           loc="upper center", bbox_to_anchor=(0.5, 0.93),  # under the title
           ncol=2, frameon=True, edgecolor="black",
           prop={"weight":"bold"})

# leave space for suptitle + legend
plt.subplots_adjust(top=0.82)

ax.grid(axis="y", linestyle=":", alpha=0.5)
ax.spines["top"].set_visible(False); ax.spines["right"].set_visible(False)

plt.tight_layout()
plt.show()

# %%
df.columns.to_list()
# Out:
# ['id',
#  'gl',
#  'time',
#  'gender',
#  'race',
#  'edulevel',
#  'annualinc',
#  'maritalstatus',
#  'dayswkex',
#  'dayswkdrinkalc',
#  'daysmonbingealc',
#  't1ddiagage',
#  'numhospdka',
#  'numshsincet1ddiag',
#  'insdeliverymethod',
#  'unitsinstotal',
#  'nummetercheckday',
#  'height',
#  'weight',
#  'hypertension',
#  'hyperlipidemia',
#  'hypothyroidism',
#  'depression',
#  'coronary_artery_disease',
#  'diabetic_peripheral_neuropathy',
#  'dyslipidemia',
#  'chronic_kidney_disease',
#  'osteoporosis',
#  'proliferative_diabetic_retinopathy',
#  'hypercholesterolemia',
#  'erectile_dysfunction',
#  'type_i_diabetes_mellitus',
#  'aspirin',
#  'simvastatin',
#  'lisinopril',
#  'vitamin_d',
#  'multivitamin_preparation',
#  'omeprazole',
#  'atorvastatin',
#  'synthroid',
#  'vitamin_d3',
#  'bmi',
#  'halfday']

# %% [markdown]
# ### 2.X Effect of Alcohol Consumption Frequency on Average Patient Glucose
#
# This plot explores how the frequency of alcohol consumption (days per week) is associated with average blood glucose levels among patients.
# Alcohol frequency is grouped into descriptive categories for clear interpretation, and both the group distributions and individual patient data are visualized.
#
# ---

# %% [markdown]
# ### 2.X Mean Glucose by Medication Group (Lollipop Plot)
#
# This lollipop plot displays the mean glucose level for patients, grouped by each medication.
# Both patients taking and not taking the medication are compared for each group.
# Values are annotated for clarity, and the legend is positioned in the upper right corner for easy reference.
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# -------------------------------
# 1) Build med_means_df from df
# -------------------------------

# List of medication columns present in your dataset (from your column list)
med_cols_all = [
    'aspirin', 'simvastatin', 'lisinopril', 'vitamin_d', 'multivitamin_preparation',
    'omeprazole', 'atorvastatin', 'synthroid', 'vitamin_d3'
]

# Keep only meds that actually exist in df
med_cols = [c for c in med_cols_all if c in df.columns]
if len(med_cols) == 0:
    raise ValueError("No medication columns found in df. Please check column names.")

# Coerce medication columns to numeric 0/1 (handles True/False/Yes/No/strings)
df_med = df.copy()
for c in med_cols:
    df_med[c] = (
        df_med[c]
        .astype(str)
        .str.strip()
        .str.lower()
        .replace({'true': 1, 'false': 0, 'yes': 1, 'no': 0, 'y': 1, 'n': 0, 'nan': np.nan})
    )
    df_med[c] = pd.to_numeric(df_med[c], errors='coerce')  # -> NaN if not parseable

# Build patient-level table: mean glucose per patient + per-medication indicator
# For medication indicator at patient level, use max() to mark as 1 if med==1 at least once.
agg_dict = {'gl': 'mean'}
agg_dict.update({c: 'max' for c in med_cols})

patient_level = (
    df_med.groupby('id', as_index=False)
          .agg(agg_dict)
          .rename(columns={'gl': 'mean_glucose'})
)

# Ensure medication columns are 0/1 (NaN -> 0 meaning "no evidence of taking")
for c in med_cols:
    patient_level[c] = patient_level[c].fillna(0).clip(lower=0, upper=1).astype(int)

# Compute mean glucose for "takes med" vs "no med" at the PATIENT level
rows = []
min_group_size = 5  # avoid tiny groups misleading the averages; adjust if needed

for med in med_cols:
    takes_mask = patient_level[med] == 1
    no_mask    = patient_level[med] == 0

    n_takes = takes_mask.sum()
    n_no    = no_mask.sum()

    # Skip if either group is too small
    if n_takes < min_group_size or n_no < min_group_size:
        continue

    mean_with = patient_level.loc[takes_mask, 'mean_glucose'].mean()
    mean_without = patient_level.loc[no_mask, 'mean_glucose'].mean()

    rows.append({
        'Medication': med.replace('_', ' ').title(),
        'N (Takes Med)': int(n_takes),
        'N (No Med)': int(n_no),
        'Glucose (Takes Med)': float(mean_with),
        'Glucose (No Med)': float(mean_without),
        'Δ (With - Without)': float(mean_with - mean_without)
    })

if len(rows) == 0:
    raise ValueError("All medication groups are too small. Lower min_group_size or check your data.")

med_means_df = pd.DataFrame(rows).sort_values('Glucose (Takes Med)', ascending=True).reset_index(drop=True)
print(med_means_df)

# ---------------------------------------
# 2) Lollipop plot (your original design)
# ---------------------------------------
plt.figure(figsize=(15, 8))

y_labels = med_means_df['Medication']
y_pos    = np.arange(len(y_labels))
x_with   = med_means_df['Glucose (Takes Med)']
x_without= med_means_df['Glucose (No Med)']

# stems
plt.hlines(y_pos, x_without, x_with, color='#5A81F7', linewidth=6, zorder=1, alpha=0.35)

# endpoints
plt.scatter(x_without, y_pos, color='#424949', label='No Medication', zorder=3, s=130, marker='s',
            edgecolor='white', linewidth=2)
plt.scatter(x_with, y_pos, color='#F74C4C', label='Takes Medication', zorder=4, s=170, marker='o',
            edgecolor='white', linewidth=2)

# annotate numeric values
for xi, yi in zip(x_with, y_pos):
    plt.text(xi, yi + 0.18, f"{xi:.1f}", va='bottom', ha='center', fontsize=13,
             color='#F74C4C', fontweight='bold')
for xi, yi in zip(x_without, y_pos):
    plt.text(xi, yi - 0.18, f"{xi:.1f}", va='top', ha='center', fontsize=13,
             color='#424949', fontweight='bold')

plt.yticks(y_pos, y_labels, fontsize=13, fontweight='bold')
plt.xlabel("Mean Patient Glucose", fontsize=15, fontweight='bold')
plt.ylabel("Medication", fontsize=15, fontweight='bold')
plt.title("Mean Glucose by Medication Group ", fontsize=21, fontweight='bold')

# legend
plt.legend(
    fontsize=14,
    title="Patient Group",
    title_fontsize=15,
    loc='upper right',
    bbox_to_anchor=(1.19, 1)
)
plt.grid(axis='x', linestyle='--', alpha=0.2, linewidth=2)
plt.tight_layout()
plt.show()
# Out:
#                  Medication  N (Takes Med)  N (No Med)  Glucose (Takes Med)  \
# 0               Simvastatin             63         136             172.4276
# 1  Multivitamin Preparation             39         160             175.1324
# 2                 Vitamin D             48         151             175.9015
# 3                   Aspirin             91         108             177.7912
# 4                 Synthroid             23         176             180.6915
# 5              Atorvastatin             24         175             180.9926
# 6                Lisinopril             51         148             182.5897
# 7                Vitamin D3             20         179             182.7240
# 8                Omeprazole             29         170             186.4751
#
#    Glucose (No Med)  Δ (With - Without)
# 0          177.0059             -4.5783
# 1          175.6598             -0.5275
# 2          175.4468              0.4548
# 3          173.6735              4.1178
# ...

# %% [markdown]
# ### **Violin Plot: Glucose Distribution for Each Disease Cohort**
#
# **This plot displays the distribution of mean patient glucose for each disease cohort.
# Diseases are shown on the x-axis, and glucose values are on the y-axis.
# Bolded labels enhance clarity and professional appearance.**
#
# ---

# %%
# ============================================================
# Lollipop: Mean glucose by Disease (Has vs No disease)
# Uses columns: id, gl, and the binary disease flags below
# ============================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- disease columns (only keep those present) ---
disease_cols = [
    'hypothyroidism',
    'coronary_artery_disease',
    'diabetic_peripheral_neuropathy',
    'dyslipidemia',
    'chronic_kidney_disease',
    'osteoporosis',
    'proliferative_diabetic_retinopathy',
    'hypercholesterolemia',
    'erectile_dysfunction',
    'type_i_diabetes_mellitus'
]
disease_cols = [c for c in disease_cols if c in df.columns]
if not disease_cols:
    raise ValueError("None of the expected disease columns are in df.")

# --- per-patient mean glucose and disease flags (1 if ever present) ---
mean_gl = df.groupby('id')['gl'].mean()
flags   = df.groupby('id')[disease_cols].max().reset_index()
flags['mean_glucose'] = flags['id'].map(mean_gl)

# --- build summary: mean for has vs none, counts, diff ---
rows = []
for col in disease_cols:
    has_mask  = flags[col] == 1
    none_mask = flags[col] == 0
    n_has, n_none = int(has_mask.sum()), int(none_mask.sum())
    # require some data in both groups to plot
    if n_has < 5 or n_none < 5:
        continue
    m_has  = flags.loc[has_mask,  'mean_glucose'].mean()
    m_none = flags.loc[none_mask, 'mean_glucose'].mean()
    rows.append({
        'Disease'  : col.replace('_', ' ').title(),
        'MeanHas'  : m_has,
        'MeanNone' : m_none,
        'N_has'    : n_has,
        'N_none'   : n_none,
        'Diff'     : m_has - m_none
    })

res = pd.DataFrame(rows)
if res.empty:
    raise ValueError("Not enough data per disease to plot (need ≥5 in each group).")

# sort by difference (disease – no disease)
res = res.sort_values('Diff', ascending=True).reset_index(drop=True)

# --- plot ---
plt.rcParams.update({"axes.edgecolor":"#111","axes.linewidth":1.6,"font.size":12})
fig, ax = plt.subplots(figsize=(14, 7))
ax.set_facecolor("#fcfcfd")

y = np.arange(len(res))

# connecting bars (No disease -> Has disease)
ax.hlines(y, res['MeanNone'], res['MeanHas'], color="#c7d2fe", linewidth=10, alpha=0.9)

# endpoints
ax.scatter(res['MeanNone'], y, s=90, marker='s', color="#374151", label="No Disease", zorder=3)
ax.scatter(res['MeanHas'],  y, s=90, marker='o', color="#ef4444", label="Has Disease", zorder=3)

# numeric labels near points
for yi, (m0, m1) in enumerate(zip(res['MeanNone'], res['MeanHas'])):
    ax.text(m0 - 0.4, yi + 0.20, f"{m0:.1f}", ha="right", va="bottom", fontsize=10, color="#374151")
    ax.text(m1 + 0.4, yi + 0.20, f"{m1:.1f}", ha="left",  va="bottom", fontsize=10, color="#ef4444")

# y labels with counts
ax.set_yticks(y)
ax.set_yticklabels([f"{d}  (n₁={nh}, n₀={nn})" for d, nh, nn in zip(res['Disease'], res['N_has'], res['N_none'])])

# axes & title
ax.set_xlabel("Mean Patient Glucose (mg/dL)", fontsize=13, fontweight="bold")
ax.set_ylabel("Disease", fontsize=13, fontweight="bold")
ax.set_title("Mean Glucose by Disease Group (Lollipop: No Disease → Has Disease)", fontsize=18, fontweight="bold", pad=10)

# clinical reference lines
for thr in (115, 180):
    ax.axvline(thr, ls="--", lw=1.4, color="#1f77b4", alpha=0.9)

# cosmetics
ax.grid(axis="x", linestyle=":", alpha=0.45)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.legend(title="Patient Group", frameon=True, loc="center left", bbox_to_anchor=(1.02, 0.5))

plt.tight_layout()
plt.show()
# Out:
# /var/folders/wk/6g53_52x66xbm6gmgx0krkb40000gn/T/ipykernel_71860/2813952607.py:97: UserWarning:
#
# Glyph 8321 (\N{SUBSCRIPT ONE}) missing from font(s) Arial.
#
# /var/folders/wk/6g53_52x66xbm6gmgx0krkb40000gn/T/ipykernel_71860/2813952607.py:97: UserWarning:
#
# Glyph 8320 (\N{SUBSCRIPT ZERO}) missing from font(s) Arial.
#
# /opt/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning:
#
# Glyph 8321 (\N{SUBSCRIPT ONE}) missing from font(s) Arial.
#
# /opt/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning:
#
# Glyph 8320 (\N{SUBSCRIPT ZERO}) missing from font(s) Arial.

# %% [markdown]
# ### **Feature Engineering for Time Series Forecasting**
#
# **Effective forecasting of glucose requires careful handling of temporal data.
# Raw datetime columns cannot be used directly in most models; instead, we extract informative time-based features from the timestamp for each measurement.
# Typical engineered features include hour of the day, day of the week, day of the month, and month, which may help capture diurnal or seasonal patterns in glucose variability.
# These engineered features, combined with patient attributes and prior glucose values, form the input for machine learning and deep learning models such as Random Forest, LSTM, and GRU.**

# %%
import pandas as pd
import numpy as np

# Ensure 'time' is a datetime column
df['time'] = pd.to_datetime(df['time'])

# Sort by patient and time to maintain correct order for lags
df = df.sort_values(['id', 'time']).reset_index(drop=True)

# Extract time-based features
df['hour'] = df['time'].dt.hour
df['dayofweek'] = df['time'].dt.dayofweek
df['day'] = df['time'].dt.day
df['month'] = df['time'].dt.month

# Convert all categorical/interval columns to codes
for col in df.select_dtypes(['category']).columns:
    df[f'{col}_code'] = df[col].cat.codes

# Optionally drop original interval/categorical columns after conversion
df = df.drop(columns=df.select_dtypes(['category']).columns)

# Create lagged glucose features for each patient
df['gl_lag1'] = df.groupby('id')['gl'].shift(1)
df['gl_lag2'] = df.groupby('id')['gl'].shift(2)

# Drop rows where lag features are NA (optional, for models that require full history)
df = df.dropna(subset=['gl_lag1', 'gl_lag2'])

# Build list of numeric, model-ready features (excluding ID, target, and time)
feature_cols = [
    col for col in df.columns
    if col not in ['id', 'gl', 'time'] and np.issubdtype(df[col], np.number)
]

# Preview engineered DataFrame
print(df[['id', 'time', 'gl', 'hour', 'dayofweek', 'day', 'month', 'gl_lag1', 'gl_lag2']].head())
print("\nModel-ready feature columns:", feature_cols)
# Out:
#    id                time       gl  hour  dayofweek  day  month  gl_lag1  \
# 2   1 1900-01-01 18:45:14 233.0000    18          0    1      1 221.0000
# 3   1 1900-01-01 18:50:14 223.0000    18          0    1      1 233.0000
# 4   1 1900-01-01 18:55:14 214.0000    18          0    1      1 223.0000
# 5   1 1900-01-01 19:00:14 211.0000    19          0    1      1 214.0000
# 6   1 1900-01-01 19:05:14 206.0000    19          0    1      1 211.0000
#
#    gl_lag2
# 2 223.0000
# 3 221.0000
# 4 233.0000
# 5 223.0000
# 6 214.0000
#
# ...

# %% [markdown]
# precition

# %%
# # Reload the newly uploaded file
# # file_path_new = '/Users/mine/office/finalyearproject/raw_data/split/weinstock-10-single.csv'
# df_new = pd.read_csv(file_path_new)

# Show the columns and a sample to confirm structure
# columns_new = df_new.columns.tolist()
# df_new_sample = df_new.head(3)
# columns_new, df_new_sample

# Parse timestamp and sort
df["time"] = pd.to_datetime(df["time"], errors='coerce')
df_new = df.sort_values("time").reset_index(drop=True)

# Create lag and rolling features for glucose
for lag in [1, 2, 3,4,5,6]:
    df_new[f"lag_{lag}"] = df_new["gl"].shift(lag)
for window in [3, 6, 12]:
    df_new[f"roll_mean_{window}"] = df_new["gl"].rolling(window=window).mean()

# Drop rows with NaNs created by lags/rolls
feature_cols = [f"lag_{lag}" for lag in [1, 2, 3,4,5,6]] + [f"roll_mean_{w}" for w in [3, 6, 12]]
df_feat = df_new.dropna(subset=feature_cols)

# Correlations
corrs = df_feat[["gl"] + feature_cols].corr()["gl"].sort_values(ascending=False)

# Show a sample and correlation for analysis selection
df_feat_sample = df_feat[["time", "gl"] + feature_cols].head(10)
corrs, df_feat_sample
# Out:
# (gl             1.0000
#  roll_mean_3    0.5948
#  roll_mean_6    0.4375
#  roll_mean_12   0.3285
#  lag_2          0.0368
#  lag_6          0.0356
#  lag_3          0.0318
#  lag_4          0.0288
#  lag_5          0.0286
#  lag_1          0.0184
#  Name: gl, dtype: float64,
#                    time       gl    lag_1    lag_2    lag_3    lag_4    lag_5  \
#  11 1899-12-27 21:43:58 106.0000 112.0000 128.0000 137.0000 145.0000 154.0000
#  12 1899-12-27 21:48:58 112.0000 106.0000 112.0000 128.0000 137.0000 145.0000
#  13 1899-12-27 22:43:58 138.0000 112.0000 106.0000 112.0000 128.0000 137.0000
#  14 1899-12-27 22:48:58 139.0000 138.0000 112.0000 106.0000 112.0000 128.0000
#  15 1899-12-27 22:58:58 156.0000 139.0000 138.0000 112.0000 106.0000 112.0000
#  16 1899-12-27 23:03:58 149.0000 156.0000 139.0000 138.0000 112.0000 106.0000
#  17 1899-12-27 23:13:58 150.0000 149.0000 156.0000 139.0000 138.0000 112.0000
# ...

# %% [markdown]
# Imports

# %% [markdown]
# 🎲  1 — Reproducibility

# %%
# ---------------- [Reproducibility] ----------------
SEED = 42
os.environ["PYTHONHASHSEED"] = str(SEED)
os.environ["TF_DETERMINISTIC_OPS"] = "1"
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ⚙️ 2 — Config

# %%
PATIENT_ID_COL = 'id'
TEST_WINDOW = 60
SEQ_LEN = 12
N_PATIENTS = 10 # Only used if you later add per-patient visuals
VAL_FRAC = 0.10 # Chronological validation fraction
THRESH = 140.0 # mg/dL threshold for confusion-matrix binarization
EPOCHS = 20
BATCH_SIZE = 128

# %% [markdown]
# 3 — Load & Sort

# %%
df["time"] = pd.to_datetime(df["time"])
df = df.sort_values([PATIENT_ID_COL, "time"]).reset_index(drop=True)
all_patient_ids = df[PATIENT_ID_COL].unique()
patient_ids_to_plot = all_patient_ids[:N_PATIENTS]
len(all_patient_ids), df.shape
# Out:
# (199, (644632, 49))

# %% [markdown]
# 4 — Feature Engineering (5‑min resample + lags)

# %%
# ---------------- [Feature Engineering: 5-min resample + lags] ----------------
dfs = []
for pid in all_patient_ids:
    df_p = df[df[PATIENT_ID_COL] == pid].copy()
    df_p = df_p.set_index("time").resample("5min")["gl"].mean().reset_index()
    df_p[PATIENT_ID_COL] = pid
    for lag in range(1, SEQ_LEN + 1):
        df_p[f"lag_{lag}"] = df_p["gl"].shift(lag)
    dfs.append(df_p)


df_feat = pd.concat(dfs, ignore_index=True)
feature_cols = [f"lag_{lag}" for lag in range(1, SEQ_LEN + 1)]
all_cols = feature_cols + ["gl"]
df_clean = df_feat.dropna(subset=all_cols).copy().reset_index(drop=True)


df_clean.head(3)
# Out:
#                  time       gl  id    lag_1    lag_2    lag_3    lag_4  \
# 0 1900-01-01 19:45:00 185.0000   1 192.0000 202.0000 198.0000 189.0000
# 1 1900-01-01 19:50:00 173.0000   1 185.0000 192.0000 202.0000 198.0000
# 2 1900-01-01 19:55:00 157.0000   1 173.0000 185.0000 192.0000 202.0000
#
#      lag_5    lag_6    lag_7    lag_8    lag_9   lag_10   lag_11   lag_12
# 0 198.0000 219.0000 208.0000 206.0000 211.0000 214.0000 223.0000 233.0000
# 1 189.0000 198.0000 219.0000 208.0000 206.0000 211.0000 214.0000 223.0000
# 2 198.0000 189.0000 198.0000 219.0000 208.0000 206.0000 211.0000 214.0000

# %% [markdown]
# 5 — Build Windowed Dataset

# %%
# ---------------- [Build Windowed Dataset] ----------------
X, y, ids = [], [], []
for pid in all_patient_ids:
    sub = df_clean[df_clean[PATIENT_ID_COL] == pid]
    # all but last TEST_WINDOW used as train/val pool; last TEST_WINDOW used as test
    for i in range(len(sub) - TEST_WINDOW):
        X.append(sub.iloc[i][feature_cols].values.astype(float))
        y.append(sub.iloc[i]["gl"])
        ids.append(pid)


X = np.stack(X)
y = np.array(y)
ids = np.array(ids)


X.shape, y.shape
# Out:
# ((480054, 12), (480054,))

# %% [markdown]
# 6 — Chronological Patient-wise Train/Test Split

# %%
# ---------------- [Chronological Patient-wise Train/Test Split] ----------------
test_mask = np.zeros_like(ids, dtype=bool)
for pid in all_patient_ids:
    pid_idx = np.where(ids == pid)[0]
    if len(pid_idx) < TEST_WINDOW + 1:
        continue
    test_mask[pid_idx[-TEST_WINDOW:]] = True


train_mask = ~test_mask


X_train_pool, y_train_pool = X[train_mask], y[train_mask]
X_test, y_test = X[test_mask], y[test_mask]
ids_test = ids[test_mask]


X_train_pool.shape, X_test.shape
# Out:
# ((468234, 12), (11820, 12))

# %% [markdown]
# 7 — Scaling (fit on TRAIN pool only)

# %%
scaler_X = StandardScaler().fit(X_train_pool)
scaler_y = StandardScaler().fit(y_train_pool.reshape(-1, 1))


X_train_pool_scaled = scaler_X.transform(X_train_pool)
X_test_scaled = scaler_X.transform(X_test)
y_train_pool_scaled = scaler_y.transform(y_train_pool.reshape(-1, 1))
y_test_scaled = scaler_y.transform(y_test.reshape(-1, 1))

# %% [markdown]
# 8 — Chronological Train/Val Split (no shuffle)

# %%
n_pool = len(X_train_pool_scaled)
n_val = max(1, int(n_pool * VAL_FRAC))
n_tr = n_pool - n_val


X_tr = X_train_pool_scaled[:n_tr]
y_tr = y_train_pool_scaled[:n_tr]
X_val = X_train_pool_scaled[n_tr:]
y_val = y_train_pool_scaled[n_tr:]


n_tr, n_val
# Out:
# (421411, 46823)

# %% [markdown]
# 9 — Reshape to Sequences

# %%
X_tr_seq = X_tr.reshape((-1, SEQ_LEN, 1))
X_val_seq = X_val.reshape((-1, SEQ_LEN, 1))
X_test_seq = X_test_scaled.reshape((-1, SEQ_LEN, 1))


X_tr_seq.shape, X_val_seq.shape, X_test_seq.shape
# Out:
# ((421411, 12, 1), (46823, 12, 1), (11820, 12, 1))

# %% [markdown]
# 10 — Callbacks

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %% [markdown]
# 12 — Model Builders (Baseline)

# %%
def build_lstm(input_shape):
    model = Sequential([
        LSTM(64, input_shape=input_shape, return_sequences=False),
        Dropout(0.2),
        Dense(64, activation='relu'),
        Dense(1)
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
    return model


def build_gru(input_shape):
    model = Sequential([
    GRU(64, input_shape=input_shape, return_sequences=False),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dense(1)
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
    return model


def build_cnn(input_shape):
    model = Sequential([
        Conv1D(64, kernel_size=4, activation='relu', input_shape=input_shape),
        Dropout(0.2),
        Flatten(),
        Dense(64, activation='relu'),
        Dense(1)
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
    return model

# %% [markdown]
# 13 — Train + Report Helper

# %%
def train_and_report(model_fn, name, epochs=EPOCHS, batch_size=BATCH_SIZE):
    print(f"\n--- Training {name} on TRAIN with VAL ---\n")
    model = model_fn((SEQ_LEN, 1))
    history = model.fit(
    X_tr_seq, y_tr,
    epochs=epochs, batch_size=batch_size, verbose=2,
    validation_data=(X_val_seq, y_val),
    shuffle=False,
    callbacks=[early_stop]
    )


    # Best val epoch
    val_losses = history.history.get('val_loss', [])
    if len(val_losses) > 0:
        best_epoch = int(np.argmin(val_losses)) + 1
        print(f"{name} best val_loss: {np.min(val_losses):.6f} at epoch {best_epoch}")


    # Predictions (inverse-transform to original glucose scale)
    y_tr_pred = scaler_y.inverse_transform(model.predict(X_tr_seq)).flatten()
    y_val_pred = scaler_y.inverse_transform(model.predict(X_val_seq)).flatten()
    y_test_pred = scaler_y.inverse_transform(model.predict(X_test_seq)).flatten()
    y_tr_inv = scaler_y.inverse_transform(y_tr).flatten()
    y_val_inv = scaler_y.inverse_transform(y_val).flatten()


    # Regression metrics
    def metrics_block(y_true, y_pred):
        r2 = r2_score(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        mae = mean_absolute_error(y_true, y_pred)
        return r2, rmse, mae


    r2_tr, rmse_tr, mae_tr = metrics_block(y_tr_inv, y_tr_pred)
    r2_val, rmse_val, mae_val = metrics_block(y_val_inv, y_val_pred)
    r2_te, rmse_te, mae_te = metrics_block(y_test, y_test_pred)


    print(f"\n{name} PERFORMANCE")
    print(f" Train: R²={r2_tr:.3f} | RMSE={rmse_tr:.3f} | MAE={mae_tr:.3f}")
    print(f" Val : R²={r2_val:.3f} | RMSE={rmse_val:.3f} | MAE={mae_val:.3f}")
    print(f" Test : R²={r2_te:.3f} | RMSE={rmse_te:.3f} | MAE={mae_te:.3f}")
    print(f" Generalization gap (Train→Val) RMSE: {rmse_val - rmse_tr:+.3f} | MAE: {mae_val - mae_tr:+.3f}")
    print(f" Generalization gap (Train→Test) RMSE: {rmse_te - rmse_tr:+.3f} | MAE: {mae_te - mae_tr:+.3f}")


    # Classification (threshold-based)
    y_test_bin = (y_test >= THRESH).astype(int)
    y_pred_bin = (y_test_pred >= THRESH).astype(int)
    cm = confusion_matrix(y_test_bin, y_pred_bin, labels=[0, 1])
    acc = accuracy_score(y_test_bin, y_pred_bin)
    prec= precision_score(y_test_bin, y_pred_bin, zero_division=0)
    rec = recall_score(y_test_bin, y_pred_bin, zero_division=0)
    f1 = f1_score(y_test_bin, y_pred_bin, zero_division=0)
    cls_metrics = dict(accuracy=acc, precision=prec, recall=rec, f1=f1, confusion_matrix=cm)


    # Return for plots + tables
    return model, history, (y_tr_inv, y_tr_pred, y_val_inv, y_val_pred, y_test, y_test_pred), (r2_te, rmse_te, mae_te), cls_metrics

# %% [markdown]
# 13 — Train All Models (Baseline)

# %%
lstm_model, history_lstm, (ytr_l, ytrp_l, yv_l, yvp_l, yt, yp_l), metrics_l, cls_l = train_and_report(build_lstm, "LSTM")
gru_model, history_gru, (ytr_g, ytrp_g, yv_g, yvp_g, yt, yp_g), metrics_g, cls_g = train_and_report(build_gru, "GRU")
cnn_model, history_cnn, (ytr_c, ytrp_c, yv_c, yvp_c, yt, yp_c), metrics_c, cls_c = train_and_report(build_cnn, "CNN")
# Out:
# --- Training LSTM on TRAIN with VAL ---
#
# Epoch 1/20
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 3293/3293 - 17s - 5ms/step - loss: 0.0440 - val_loss: 0.0168
# Epoch 2/20
# 3293/3293 - 17s - 5ms/step - loss: 0.0192 - val_loss: 0.0272
# Epoch 3/20
# 3293/3293 - 16s - 5ms/step - loss: 0.0150 - val_loss: 0.0404
# Epoch 4/20
# 3293/3293 - 16s - 5ms/step - loss: 0.0130 - val_loss: 0.0383
# Epoch 5/20
# 3293/3293 - 17s - 5ms/step - loss: 0.0107 - val_loss: 0.0426
# Epoch 6/20
# 3293/3293 - 15s - 4ms/step - loss: 0.0094 - val_loss: 0.0450
# LSTM best val_loss: 0.016833 at epoch 1
# 13170/13170 ━━━━━━━━━━━━━━━━━━━━ 9s 698us/step
# 1464/1464 ━━━━━━━━━━━━━━━━━━━━ 1s 674us/step
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
#
# LSTM PERFORMANCE
# ...

# %% [markdown]
# 14 — Aggregate R² Summary (Baseline)

# %%
print("\nAGGREGATE R² SCORES (all test points, all patients) — BASELINE:")
print(f"LSTM: {metrics_l[0]:.3f}")
print(f"GRU : {metrics_g[0]:.3f}")
print(f"CNN : {metrics_c[0]:.3f}")
# Out:
# AGGREGATE R² SCORES (all test points, all patients) — BASELINE:
# LSTM: 0.988
# GRU : 0.981
# CNN : 0.995

# %% [markdown]
# 15 — Hyperparameter Tuning: Builders

# %%
# ====================== [Hyperparameter Tuning] ======================
# Small, deterministic manual grid with a cap on trials to keep runtime practical.


def build_lstm_param(input_shape, units=64, dropout=0.2, dense_units=64, lr=1e-3):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(units, return_sequences=False),
        Dropout(dropout),
        Dense(dense_units, activation='relu'),
        Dense(1)
    ])
    model.compile(optimizer=Adam(learning_rate=lr), loss='mse')
    return model


def build_gru_param(input_shape, units=64, dropout=0.2, dense_units=64, lr=1e-3):
    model = Sequential([
        Input(shape=input_shape),
        GRU(units, return_sequences=False),
        Dropout(dropout),
        Dense(dense_units, activation='relu'),
        Dense(1)
    ])
    model.compile(optimizer=Adam(learning_rate=lr), loss='mse')
    return model


def build_cnn_param(input_shape, filters=64, kernel_size=4, dropout=0.2, dense_units=64, lr=1e-3):
    model = Sequential([
        Input(shape=input_shape),
        Conv1D(filters, kernel_size=kernel_size, activation='relu'),
        Dropout(dropout),
        Flatten(),
        Dense(dense_units, activation='relu'),
        Dense(1)
    ])
    model.compile(optimizer=Adam(learning_rate=lr), loss='mse')
    return model

# %% [markdown]
# 16 — Tuning Utilities

# %%
def try_params(make_model_fn, name, params, epochs=EPOCHS, batch_size=BATCH_SIZE):
    """Train once with given params; return val_rmse and artifacts."""
    model = make_model_fn((SEQ_LEN, 1), **params)
    hist = model.fit(
        X_tr_seq, y_tr,
        epochs=epochs, batch_size=batch_size, verbose=0,
        validation_data=(X_val_seq, y_val),
        shuffle=False,
        callbacks=[early_stop]
    )
    # compute validation RMSE in original scale
    y_val_pred = scaler_y.inverse_transform(model.predict(X_val_seq, verbose=0)).flatten()
    y_val_inv = scaler_y.inverse_transform(y_val).flatten()
    val_rmse = np.sqrt(mean_squared_error(y_val_inv, y_val_pred))
    return val_rmse, model, hist

def best_of_grid(name, make_model_fn, grid, max_trials=12, epochs=EPOCHS, batch_size=BATCH_SIZE):
    # cartesian product
    keys = list(grid.keys())
    all_combos = list(itertools.product(*[grid[k] for k in keys]))
    # deterministic shuffle then cap
    rng = np.random.default_rng(SEED)
    rng.shuffle(all_combos)
    combos = all_combos[:max_trials] if max_trials else all_combos


    results = []
    best = (np.inf, None, None, None) # (val_rmse, params, model, hist)
    print(f"\n>>> TUNING {name}: trying {len(combos)} configs (cap={max_trials})")
    for i, combo in enumerate(combos, 1):
        params = dict(zip(keys, combo))
        val_rmse, model, hist = try_params(make_model_fn, name, params, epochs, batch_size)
        results.append((val_rmse, params))
        if val_rmse < best[0]:
            best = (val_rmse, params, model, hist)
        print(f"[{i:02d}/{len(combos)}] val_RMSE={val_rmse:.4f} | params={params}")
    print(f"BEST {name} params (by val RMSE): {best[1]} -> val_RMSE={best[0]:.4f}")
    return best, results

# %% [markdown]
# 17 — Tuning Grids & Run Tuning

# %%
lstm_grid = {
    "units": [32, 64, 96, 128],
    "dropout": [0.1, 0.2, 0.3],
    "dense_units": [32, 64, 96],
    "lr": [1e-3, 5e-4],
}
gru_grid = {
    "units": [32, 64, 96, 128],
    "dropout": [0.1, 0.2, 0.3],
    "dense_units": [32, 64, 96],
    "lr": [1e-3, 5e-4],
}
cnn_grid = {
    "filters": [32, 64, 96],
    "kernel_size": [3, 5, 7],
    "dropout": [0.1, 0.2, 0.3],
    "dense_units": [32, 64, 96],
    "lr": [1e-3, 5e-4],
}


MAX_TRIALS_PER_MODEL = 12 # adjust if you want deeper sweeps


(best_lstm, lstm_trials) = best_of_grid("LSTM", build_lstm_param, lstm_grid, MAX_TRIALS_PER_MODEL, EPOCHS, BATCH_SIZE)
(best_gru, gru_trials) = best_of_grid("GRU", build_gru_param, gru_grid, MAX_TRIALS_PER_MODEL, EPOCHS, BATCH_SIZE)
(best_cnn, cnn_trials) = best_of_grid("CNN", build_cnn_param, cnn_grid, MAX_TRIALS_PER_MODEL, EPOCHS, BATCH_SIZE)
# Out:
# >>> TUNING LSTM: trying 12 configs (cap=12)
# [01/12] val_RMSE=8.2834 | params={'units': 96, 'dropout': 0.3, 'dense_units': 32, 'lr': 0.001}
# [02/12] val_RMSE=9.1590 | params={'units': 64, 'dropout': 0.2, 'dense_units': 96, 'lr': 0.001}
# [03/12] val_RMSE=8.5522 | params={'units': 64, 'dropout': 0.1, 'dense_units': 32, 'lr': 0.001}
# [04/12] val_RMSE=9.0061 | params={'units': 64, 'dropout': 0.2, 'dense_units': 32, 'lr': 0.0005}
# [05/12] val_RMSE=8.7769 | params={'units': 96, 'dropout': 0.1, 'dense_units': 64, 'lr': 0.0005}
# [06/12] val_RMSE=9.3276 | params={'units': 96, 'dropout': 0.1, 'dense_units': 32, 'lr': 0.0005}
# [07/12] val_RMSE=8.0467 | params={'units': 128, 'dropout': 0.2, 'dense_units': 32, 'lr': 0.001}
# [08/12] val_RMSE=7.9287 | params={'units': 96, 'dropout': 0.3, 'dense_units': 64, 'lr': 0.001}
# [09/12] val_RMSE=11.5638 | params={'units': 64, 'dropout': 0.3, 'dense_units': 64, 'lr': 0.0005}
# ...

# %% [markdown]
# 18 — Evaluate Best Tuned Models

# %%
def evaluate_model_full(trained_model, name):
    y_tr_pred = scaler_y.inverse_transform(trained_model.predict(X_tr_seq, verbose=0)).flatten()
    y_val_pred = scaler_y.inverse_transform(trained_model.predict(X_val_seq, verbose=0)).flatten()
    y_test_pred = scaler_y.inverse_transform(trained_model.predict(X_test_seq,verbose=0)).flatten()


    y_tr_inv = scaler_y.inverse_transform(y_tr).flatten()
    y_val_inv = scaler_y.inverse_transform(y_val).flatten()


    def metrics_block(y_true, y_pred):
        r2 = r2_score(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        mae = mean_absolute_error(y_true, y_pred)
        return r2, rmse, mae


    r2_tr, rmse_tr, mae_tr = metrics_block(y_tr_inv, y_tr_pred)
    r2_val, rmse_val, mae_val = metrics_block(y_val_inv, y_val_pred)
    r2_te, rmse_te, mae_te = metrics_block(y_test, y_test_pred)


    print(f"\n[TUNED] {name} PERFORMANCE")
    print(f" Train: R²={r2_tr:.3f} | RMSE={rmse_tr:.3f} | MAE={mae_tr:.3f}")
    print(f" Val : R²={r2_val:.3f} | RMSE={rmse_val:.3f} | MAE={mae_val:.3f}")
    print(f" Test : R²={r2_te:.3f} | RMSE={rmse_te:.3f} | MAE={mae_te:.3f}")


    # classification @ THRESH
    y_test_bin = (y_test >= THRESH).astype(int)
    y_pred_bin = (y_test_pred >= THRESH).astype(int)
    cm = confusion_matrix(y_test_bin, y_pred_bin, labels=[0, 1])
    acc = accuracy_score(y_test_bin, y_pred_bin)
    prec= precision_score(y_test_bin, y_pred_bin, zero_division=0)
    rec = recall_score(y_test_bin, y_pred_bin, zero_division=0)
    f1 = f1_score(y_test_bin, y_pred_bin, zero_division=0)
    cls = dict(accuracy=acc, precision=prec, recall=rec, f1=f1, confusion_matrix=cm)


    return (y_tr_inv, y_tr_pred, y_val_inv, y_val_pred, y_test, y_test_pred), (r2_te, rmse_te, mae_te), cls


# Extract best trained models from tuning step
best_lstm_model = best_lstm[2]
best_gru_model = best_gru[2]
best_cnn_model = best_cnn[2]


(ytr_l_t, ytrp_l_t, yv_l_t, yvp_l_t, yt_t, yp_l_t), metrics_l_t, cls_l_t = evaluate_model_full(best_lstm_model, "LSTM")
(ytr_g_t, ytrp_g_t, yv_g_t, yvp_g_t, yt_t, yp_g_t), metrics_g_t, cls_g_t = evaluate_model_full(best_gru_model, "GRU")
(ytr_c_t, ytrp_c_t, yv_c_t, yvp_c_t, yt_t, yp_c_t), metrics_c_t, cls_c_t = evaluate_model_full(best_cnn_model, "CNN")
# Out:
# [TUNED] LSTM PERFORMANCE
#  Train: R²=0.993 | RMSE=6.974 | MAE=4.926
#  Val : R²=0.993 | RMSE=6.850 | MAE=4.779
#  Test : R²=0.995 | RMSE=6.126 | MAE=4.377
#
# [TUNED] GRU PERFORMANCE
#  Train: R²=0.992 | RMSE=7.335 | MAE=5.343
#  Val : R²=0.992 | RMSE=7.380 | MAE=5.291
#  Test : R²=0.993 | RMSE=6.835 | MAE=5.043
#
# [TUNED] CNN PERFORMANCE
#  Train: R²=0.995 | RMSE=5.935 | MAE=3.759
#  Val : R²=0.995 | RMSE=5.879 | MAE=3.624
#  Test : R²=0.996 | RMSE=5.024 | MAE=3.118

# %% [markdown]
# 20 — Plot Helpers: Identity Scatters & Lines

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error


def _metrics(y_true, y_pred):
    r2 = r2_score(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse= np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    return r2, mse, rmse, mae




def _nice_limits(y_list, pad=0.03):
    lo = float(min(np.min(arr) for arr in y_list))
    hi = float(max(np.max(arr) for arr in y_list))
    span = hi - lo
    if span <= 0:
        span = max(1.0, abs(lo) * 0.1)
    lo -= pad * span
    hi += pad * span
    return lo, hi




def plot_train_test_scatter(y_tr, y_tr_pred, y_te, y_te_pred,
                            model_name="Model",
                            use_hexbin=False, gridsize=60):
    # ---------- Metrics ----------
    r2_tr  = r2_score(y_tr, y_tr_pred);  mse_tr  = mean_squared_error(y_tr, y_tr_pred)
    rmse_tr= np.sqrt(mse_tr);            mae_tr  = mean_absolute_error(y_tr, y_tr_pred)
    r2_te  = r2_score(y_te, y_te_pred);  mse_te  = mean_squared_error(y_te, y_te_pred)
    rmse_te= np.sqrt(mse_te);            mae_te  = mean_absolute_error(y_te, y_te_pred)

    # More headroom so points/lines aren’t clipped at top-right
    def _nice_limits(y_list, pad=0.06):  # ↑ pad from 0.03 -> 0.06
        lo = float(min(np.min(arr) for arr in y_list))
        hi = float(max(np.max(arr) for arr in y_list))
        span = hi - lo if hi > lo else max(1.0, abs(lo) * 0.1)
        return lo - pad*span, hi + pad*span

    lo, hi = _nice_limits([y_tr, y_tr_pred, y_te, y_te_pred])

    # ---------- Palette ----------
    pt_color     = "#3B82F6"   # blue points
    id_line_col  = "#F59E0B"   # amber identity
    fit_line_col = "#DC2626"   # deep red best-fit

    fig, axes = plt.subplots(1, 2, figsize=(16, 6), facecolor="white")
    fig.suptitle(f"{model_name} — Train vs Test ",
                 fontsize=18, fontweight='bold')

    panels = [
        ("Train", y_tr, y_tr_pred, (r2_tr, rmse_tr, mse_tr, mae_tr)),
        ("Test",  y_te, y_te_pred, (r2_te, rmse_te, mse_te, mae_te)),
    ]

    for ax, (title, yy, yp, stats) in zip(axes, panels):
        r2, rmse, mse, mae = stats
        ax.set_facecolor("#FAFAFA")

        # Points
        if use_hexbin:
            hb = ax.hexbin(yy, yp, gridsize=gridsize, mincnt=1, cmap="Blues", linewidths=0)
            cb = plt.colorbar(hb, ax=ax, fraction=0.046, pad=0.02); 
            for t in cb.ax.get_yticklabels(): t.set_fontweight("bold")
        else:
            ax.scatter(yy, yp, s=10, alpha=0.35, linewidths=0, color=pt_color, zorder=1)

        # Identity line (dashed amber), Best-fit line (solid red)
        ax.plot([lo, hi], [lo, hi], linestyle='--', linewidth=2.2, color=id_line_col,
                label="Identity", zorder=2, solid_capstyle="round")
        if len(yy) > 1:
            m, b = np.polyfit(yy, yp, 1)
            ax.plot([lo, hi], [m*lo + b, m*hi + b], linewidth=2.4, color=fit_line_col,
                    label="Best fit", zorder=3, solid_capstyle="round")

        # Limits, margins, and aspect
        ax.set_xlim(lo, hi); ax.set_ylim(lo, hi)
        ax.margins(x=0.00, y=0.00)  # keep our manual margins
        ax.set_aspect('equal', adjustable='box')

        # Grid & labels (bold)
        ax.grid(True, linewidth=0.8, alpha=0.18)
        ax.set_title(title, fontsize=14, fontweight='bold', pad=10)
        ax.set_xlabel("True Glucose", fontsize=12, fontweight='bold')
        ax.set_ylabel("Predicted Glucose", fontsize=12, fontweight='bold')
        ax.tick_params(axis='both', labelsize=11, width=1.2)
        for t in ax.get_xticklabels() + ax.get_yticklabels():
            t.set_fontweight('bold')

        # Legend (bold) with distinct line styles
        leg = ax.legend(frameon=True, fontsize=11, loc="upper left")
        for txt in leg.get_texts(): txt.set_fontweight("bold")

        # Stats box
        box_txt = (f"R²   : {r2:0.3f}\n"
                   f"RMSE : {rmse:0.3f}\n"
                   f"MSE  : {mse:0.3f}\n"
                   f"MAE  : {mae:0.3f}")
        ax.text(0.98, 0.02, box_txt, transform=ax.transAxes,
                ha='right', va='bottom',
                bbox=dict(boxstyle="round,pad=0.4", fc="white", ec="#D1D5DB", alpha=0.96, lw=1.0),
                fontsize=11, fontweight='bold')

        # Spines
        for spine in ax.spines.values():
            spine.set_linewidth(1.2); spine.set_color("#9CA3AF")

    # Prevent cutting at figure borders
    plt.tight_layout(rect=[0, 0, 1, 0.93])
    plt.subplots_adjust(right=0.985, top=0.90)
    plt.show()







def plot_aggregated_identity_scatter(
    yt,
    preds_named,
    separate=True,        # True = one clean figure per model (best for visibility)
    use_hexbin=True,      # True = density hexbin; False = classic scatter
    gridsize=60,
    max_points=None,      # e.g., 100_000 to subsample if extremely large
    title_prefix="All Patients (Test) —"
):
    """
    preds_named: list of tuples like
        [("LSTM (B)", yhat_lstm, r2_l), ("GRU (B)", yhat_gru, r2_g), ...]
      or without precomputed R²:
        [("LSTM (B)", yhat_lstm), ...]  -> R² computed on the fly.

    Options:
      - separate=True   -> produce a *separate figure per model* (prevents occlusion)
      - use_hexbin=True -> use density hexbin with colorbar (great for large N)
      - max_points      -> subsample to avoid overplotting/memory in scatter mode
    """
    import numpy as np
    import matplotlib.pyplot as plt
    from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

    # ---- Helpers ----
    def _metrics(y_true, y_pred):
        r2  = r2_score(y_true, y_pred)
        mse = mean_squared_error(y_true, y_pred)
        rmse= np.sqrt(mse)
        mae = mean_absolute_error(y_true, y_pred)
        return r2, mse, rmse, mae

    def _nice_limits(arrs, pad=0.06):
        lo = float(min(np.min(a) for a in arrs))
        hi = float(max(np.max(a) for a in arrs))
        span = hi - lo if hi > lo else max(1.0, abs(lo) * 0.1)
        return lo - pad*span, hi + pad*span

    # Parse tuples (accept 2-tuple or 3-tuple)
    parsed = []
    for tup in preds_named:
        if len(tup) == 3:
            name, yhat, r2 = tup
        else:
            name, yhat = tup
            r2, *_ = _metrics(yt, yhat)
        parsed.append((name, np.asarray(yhat), float(r2)))

    # Global limits if overlaying; per-model limits if separate
    if not separate:
        lo, hi = _nice_limits([yt] + [yhat for _, yhat, _ in parsed])

    # Colors/lines
    id_line_col  = "#F59E0B"  # amber identity
    fit_line_col = "#DC2626"  # deep red best-fit
    pt_cmap      = "viridis"  # for hexbin
    pt_color     = "#2563EB"  # blue for scatter

    # Subsampling if requested (scatter mode only)
    def _maybe_subsample(y_true, y_pred):
        if (max_points is None) or (len(y_true) <= max_points) or use_hexbin:
            return y_true, y_pred
        idx = np.random.default_rng(42).choice(len(y_true), size=max_points, replace=False)
        return y_true[idx], y_pred[idx]

    # ========== Separate figures: best visibility ==========
    if separate:
        for name, yhat, r2 in parsed:
            yt_plot, yh_plot = _maybe_subsample(yt, yhat)
            lo_m, hi_m = _nice_limits([yt_plot, yh_plot])

            fig = plt.figure(figsize=(8, 7), facecolor="white")
            plt.title(f"{title_prefix} {name} — How close did we land?",
                      fontsize=16, fontweight="bold", pad=10)

            if use_hexbin:
                hb = plt.hexbin(yt_plot, yh_plot, gridsize=gridsize, mincnt=1, cmap=pt_cmap)
                cbar = plt.colorbar(hb, fraction=0.046, pad=0.02)
                for t in cbar.ax.get_yticklabels(): t.set_fontweight("bold")
            else:
                plt.scatter(yt_plot, yh_plot, s=9, alpha=0.30, linewidths=0, color=pt_color)

            # Identity & best-fit
            plt.plot([lo_m, hi_m], [lo_m, hi_m], "--", lw=2.2, color=id_line_col, label="Identity", zorder=3)
            if len(yt_plot) > 1:
                m, b = np.polyfit(yt_plot, yh_plot, 1)
                plt.plot([lo_m, hi_m], [m*lo_m + b, m*hi_m + b], lw=2.4, color=fit_line_col, label="Best fit", zorder=4)

            # Axes, labels (bold)
            plt.xlim(lo_m, hi_m); plt.ylim(lo_m, hi_m)
            plt.gca().set_aspect("equal", adjustable="box")
            plt.grid(True, linewidth=0.8, alpha=0.18)
            plt.xlabel("True Glucose",  fontsize=12, fontweight="bold")
            plt.ylabel("Predicted Glucose", fontsize=12, fontweight="bold")
            plt.tick_params(axis='both', labelsize=11, width=1.2)
            for t in plt.gca().get_xticklabels() + plt.gca().get_yticklabels():
                t.set_fontweight("bold")

            # Stats box (bold)
            r2_v, mse_v, rmse_v, mae_v = _metrics(yt_plot, yh_plot)
            box_txt = (f"R²   : {r2_v:0.3f}\n"
                       f"RMSE : {rmse_v:0.3f}\n"
                       f"MSE  : {mse_v:0.3f}\n"
                       f"MAE  : {mae_v:0.3f}")
            plt.text(0.98, 0.02, box_txt, transform=plt.gca().transAxes,
                     ha='right', va='bottom',
                     bbox=dict(boxstyle="round,pad=0.45", fc="white", ec="#D1D5DB", alpha=0.96, lw=1.0),
                     fontsize=11, fontweight="bold")

            # Legend (bold)
            leg = plt.legend(frameon=True, fontsize=11, loc="upper left")
            for txt in leg.get_texts(): txt.set_fontweight("bold")
            for s in plt.gca().spines.values():
                s.set_linewidth(1.2); s.set_color("#9CA3AF")

            plt.tight_layout()
            plt.show()

    # ========== Overlay (single figure): if you really want all together ==========
    else:
        fig = plt.figure(figsize=(8.2, 7), facecolor="white")
        plt.title(f"{title_prefix} Identity Scatter — Which model hugs the line?",
                  fontsize=16, fontweight="bold", pad=10)

        # Plot each model (scatter only in overlay to keep color meaning)
        markers = ["o", "s", "^", "D", "v", "P"]
        for i, (name, yhat, r2) in enumerate(parsed):
            yt_plot, yh_plot = _maybe_subsample(yt, yhat)
            plt.scatter(yt_plot, yh_plot, s=9, alpha=0.28, linewidths=0,
                        label=f"{name}  (R²={r2:.3f})", marker=markers[i % len(markers)])

        # Lines
        plt.plot([lo, hi], [lo, hi], "--", lw=2.2, color=id_line_col, label="Identity", zorder=3)

        # Axes/labels (bold)
        plt.xlim(lo, hi); plt.ylim(lo, hi)
        plt.gca().set_aspect("equal", adjustable="box")
        plt.grid(True, linewidth=0.8, alpha=0.18)
        plt.xlabel("True Glucose",  fontsize=12, fontweight="bold")
        plt.ylabel("Predicted Glucose", fontsize=12, fontweight="bold")
        plt.tick_params(axis='both', labelsize=11, width=1.2)
        for t in plt.gca().get_xticklabels() + plt.gca().get_yticklabels():
            t.set_fontweight("bold")

        # Legend (bold)
        leg = plt.legend(frameon=True, fontsize=11, ncol=1, loc="upper left")
        for txt in leg.get_texts(): txt.set_fontweight("bold")
        for s in plt.gca().spines.values():
            s.set_linewidth(1.2); s.set_color("#9CA3AF")

        plt.tight_layout()
        plt.show()





def plot_true_vs_models_line(y_true, y_preds_dict, start_idx=0, length=500, title=None):
    n = len(y_true)
    if n == 0:
        print("No test points to plot."); return
    
    start = max(0, min(start_idx, n-1))
    end = min(n, start + max(50, length))
    xs = np.arange(start, end)

    plt.figure(figsize=(14, 5.5))
    plt.plot(xs, y_true[start:end], linewidth=2.0, label="True")

    for name, yhat in y_preds_dict.items():
        r2_w = r2_score(y_true[start:end], yhat[start:end]) if end > start+1 else float("nan")
        plt.plot(xs, yhat[start:end], linewidth=1.6, label=f"{name} (R²={r2_w:.3f})")

    plt.xlabel("Test index (chronological within concatenated patients)", fontsize=12, fontweight="bold")
    plt.ylabel("Glucose", fontsize=12, fontweight="bold")
    plt.title(title or "True vs. Model Predictions — Test Window", fontsize=13, fontweight="bold")

    # Bold tick labels
    plt.xticks(fontsize=10, fontweight="bold")
    plt.yticks(fontsize=10, fontweight="bold")

    plt.grid(True, linewidth=0.6, alpha=0.6)
    plt.legend(frameon=True, ncol=2, fontsize=10, prop={"weight": "bold"})
    plt.tight_layout()
    plt.show()

# %% [markdown]
# 21 — Make the Plots (Baseline & Tuned)

# %%
# Baseline identity scatters
plot_train_test_scatter(ytr_l, ytrp_l, yt, yp_l, "LSTM (Baseline)")
plot_train_test_scatter(ytr_g, ytrp_g, yt, yp_g, "GRU (Baseline)")
plot_train_test_scatter(ytr_c, ytrp_c, yt, yp_c, "CNN (Baseline)")


# Tuned identity scatters
plot_train_test_scatter(ytr_l_t, ytrp_l_t, yt_t, yp_l_t, "LSTM (Tuned)")
plot_train_test_scatter(ytr_g_t, ytrp_g_t, yt_t, yp_g_t, "GRU (Tuned)")
plot_train_test_scatter(ytr_c_t, ytrp_c_t, yt_t, yp_c_t, "CNN (Tuned)")


# Aggregated — baseline vs tuned (side-by-side calls)
plot_aggregated_identity_scatter(
yt, [("LSTM (B)", yp_l, metrics_l[0]), ("GRU (B)", yp_g, metrics_g[0]), ("CNN (B)", yp_c, metrics_c[0])]
)
plot_aggregated_identity_scatter(
yt_t, [("LSTM (T)", yp_l_t, metrics_l_t[0]), ("GRU (T)", yp_g_t, metrics_g_t[0]), ("CNN (T)", yp_c_t, metrics_c_t[0])]
)


# Example windows
plot_true_vs_models_line(
yt,
{"LSTM (B)": yp_l, "GRU (B)": yp_g, "CNN (B)": yp_c},
start_idx=0, length=600, title="True vs Baseline Models — Test Window (first 600 points)"
)
plot_true_vs_models_line(
yt_t,
{"LSTM (T)": yp_l_t, "GRU (T)": yp_g_t, "CNN (T)": yp_c_t},
start_idx=0, length=600, title="True vs Tuned Models — Test Window (first 600 points)"
)

# %% [markdown]
# 23 — Training vs Validation Loss

# %%
def plot_losses(history_base, title, history_tuned=None):
    """
    If history_tuned is provided, shows Baseline (left) vs Tuned (right) side-by-side.
    Otherwise, shows a single plot. Bold axes/legend, grid, and min val-loss marker.
    """
    import numpy as np
    import matplotlib.pyplot as plt

    def _plot_one(ax, hist, label_prefix, col_train, col_val):
        ax.plot(hist.history['loss'], label=f'Train ({label_prefix})', linewidth=2.0, color=col_train)
        if 'val_loss' in hist.history:
            ax.plot(hist.history['val_loss'], label=f'Val ({label_prefix})', linewidth=2.0,
                    linestyle='--', color=col_val)
            # mark minimum val loss
            v = hist.history['val_loss']
            i = int(np.argmin(v))
            ax.plot(i, v[i], marker='o', ms=6, color=col_val)
            ax.annotate(f"min @ {i+1}\n{v[i]:.4f}", xy=(i, v[i]), xytext=(10, 10),
                        textcoords='offset points', fontsize=10, fontweight='bold',
                        bbox=dict(boxstyle="round,pad=0.25", fc="white", ec="#D1D5DB", lw=1))

        ax.set_xlabel('Epoch', fontsize=12, fontweight='bold')
        ax.set_ylabel('MSE Loss', fontsize=12, fontweight='bold')
        ax.grid(True, alpha=0.25)
        ax.tick_params(axis='both', labelsize=11, width=1.2)
        for t in ax.get_xticklabels() + ax.get_yticklabels():
            t.set_fontweight('bold')
        leg = ax.legend(frameon=True, fontsize=11, loc='upper right')
        for txt in leg.get_texts():
            txt.set_fontweight('bold')
        for s in ax.spines.values():
            s.set_linewidth(1.1); s.set_color('#9CA3AF')

    if history_tuned is None:
        plt.figure(figsize=(8, 5))
        plt.title(title, fontweight='bold')
        _plot_one(plt.gca(), history_base, 'Baseline', '#2563EB', '#10B981')
        plt.tight_layout(); plt.show()
    else:
        fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)
        fig.suptitle(title, fontsize=16, fontweight='bold')
        axes[0].set_title('Baseline', fontweight='bold')
        _plot_one(axes[0], history_base, 'Baseline', '#2563EB', '#10B981')
        axes[1].set_title('Tuned', fontweight='bold')
        _plot_one(axes[1], history_tuned, 'Tuned', '#EF4444', '#F59E0B')
        plt.tight_layout(rect=[0, 0, 1, 0.92]); plt.show()


# Baseline-only (single plot):
# plot_losses(history_lstm, "LSTM (Baseline): Training vs Validation Loss")

# Side-by-side Baseline vs Tuned (requires best_* histories from tuning):
plot_losses(history_lstm, "LSTM — Baseline vs Tuned: Training & Validation Loss", history_tuned=best_lstm[3])
plot_losses(history_gru,  "GRU — Baseline vs Tuned: Training & Validation Loss",  history_tuned=best_gru[3])
plot_losses(history_cnn,  "CNN — Baseline vs Tuned: Training & Validation Loss",  history_tuned=best_cnn[3])

# %% [markdown]
# 24 — Confusion Matrices (Baseline & Tuned, Test)

# %%
import matplotlib.colors as mcolors

def plot_confusion_matrix(cm, title):
    """
    Confusion matrix with bold labels and text that adapts to cell color.
    Works even if some values are near zero.
    """
    fig, ax = plt.subplots(figsize=(6, 5), constrained_layout=True)
    im = ax.imshow(cm, interpolation='nearest', cmap='magma')
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)

    # Bold title and axis labels
    ax.set_title(title, fontweight='bold', fontsize=14)
    ax.set_xlabel('Predicted', fontweight='bold', fontsize=12)
    ax.set_ylabel('True', fontweight='bold', fontsize=12)

    # Bold tick labels
    ax.set_xticks([0, 1], [f'<{int(THRESH)}', f'≥{int(THRESH)}'])
    ax.set_yticks([0, 1], ['True <', 'True ≥'])
    for tick in ax.get_xticklabels() + ax.get_yticklabels():
        tick.set_fontweight('bold')
        tick.set_fontsize(11)

    # Normalize values to colormap range
    norm = mcolors.Normalize(vmin=cm.min(), vmax=cm.max())

    # Overlay numbers with adaptive color (white if dark background, else black)
    for (i, j), v in np.ndenumerate(cm):
        color_val = im.cmap(norm(cm[i, j]))
        # perceived brightness: 0=dark, 1=bright
        brightness = (0.299*color_val[0] + 0.587*color_val[1] + 0.114*color_val[2])
        text_color = 'white' if brightness < 0.5 else 'black'
        ax.text(j, i, f"{int(v):,}", ha='center', va='center',
                fontsize=12, fontweight='bold', color=text_color)

    plt.show()




# Baseline CMs
plot_confusion_matrix(cls_l["confusion_matrix"], "LSTM (Baseline) — Confusion Matrix (Test)")
plot_confusion_matrix(cls_g["confusion_matrix"], "GRU (Baseline) — Confusion Matrix (Test)")
plot_confusion_matrix(cls_c["confusion_matrix"], "CNN (Baseline) — Confusion Matrix (Test)")


# Tuned CMs
plot_confusion_matrix(cls_l_t["confusion_matrix"], "LSTM (Tuned) — Confusion Matrix (Test)")
plot_confusion_matrix(cls_g_t["confusion_matrix"], "GRU (Tuned) — Confusion Matrix (Test)")
plot_confusion_matrix(cls_c_t["confusion_matrix"], "CNN (Tuned) — Confusion Matrix (Test)")

# %% [markdown]
# 25 — Test Leaderboard (Tuned)

# %%
model_names = ["LSTM (Tuned)", "GRU (Tuned)", "CNN (Tuned)"]
r2_vals_t = [metrics_l_t[0], metrics_g_t[0], metrics_c_t[0]]
rmse_vals_t = [metrics_l_t[1], metrics_g_t[1], metrics_c_t[1]]
mae_vals_t = [metrics_l_t[2], metrics_g_t[2], metrics_c_t[2]]


summary_tuned = pd.DataFrame({
    "Model": model_names,
    "R2": r2_vals_t,
    "RMSE": rmse_vals_t,
    "MAE": mae_vals_t,
    "Accuracy@TH": [cls_l_t["accuracy"], cls_g_t["accuracy"], cls_c_t["accuracy"]],
    "Precision@TH": [cls_l_t["precision"], cls_g_t["precision"], cls_c_t["precision"]],
    "Recall@TH": [cls_l_t["recall"], cls_g_t["recall"], cls_c_t["recall"]],
    "F1@TH": [cls_l_t["f1"], cls_g_t["f1"], cls_c_t["f1"]],
}).sort_values(by="R2", ascending=False).reset_index(drop=True)


print("\n===== TEST SET LEADERBOARD — TUNED =====")
print(summary_tuned.to_string(index=False, float_format=lambda v: f"{v:.3f}"))


best_idx_t = int(np.argmax(r2_vals_t))
best_name_t = model_names[best_idx_t]
print(f"\nBEST TUNED MODEL on Test (by R²): {best_name_t}")
# Out:
# ===== TEST SET LEADERBOARD — TUNED =====
#        Model    R2  RMSE   MAE  Accuracy@TH  Precision@TH  Recall@TH  F1@TH
#  CNN (Tuned) 0.996 5.024 3.118        0.983         0.991      0.981  0.986
# LSTM (Tuned) 0.995 6.126 4.377        0.981         0.993      0.976  0.984
#  GRU (Tuned) 0.993 6.835 5.043        0.985         0.986      0.989  0.988
#
# BEST TUNED MODEL on Test (by R²): CNN (Tuned)

# %%
# # --- CONFIGURE ---
# single_pid = 14 # <--- change to your patient id
# use_tuned = False # False = Baseline (yp_l/yp_g/yp_c), True = Tuned (yp_l_t/yp_g_t/yp_c_t)
# window_len = 60 # last N test points for this patient


# # --- SAFETY CHECKS ---
# assert 'ids_test' in globals(), "ids_test not found. Run the split cells first."
# assert 'y_test' in globals(), "y_test not found. Run earlier cells first."


# # Choose prediction arrays depending on baseline vs tuned
# if use_tuned:
#     assert all(v in globals() for v in ['yp_l_t','yp_g_t','yp_c_t','yt_t']), "Run tuned evaluation cells first."
#     preds = {
#     'LSTM (Tuned)': yp_l_t,
#     'GRU (Tuned)' : yp_g_t,
#     'CNN (Tuned)' : yp_c_t,
#     }
#     y_true_global = yt_t
# else:
#     assert all(v in globals() for v in ['yp_l','yp_g','yp_c','yt']), "Run baseline training cells first."
#     preds = {
#     'LSTM (Baseline)': yp_l,
#     'GRU (Baseline)' : yp_g,
#     'CNN (Baseline)' : yp_c,
#     }
#     y_true_global = yt


# # --- SELECT INDICES FOR THIS PATIENT IN THE TEST SET ---
# pidx = np.where(ids_test == single_pid)[0]
# if len(pidx) < window_len:
#     print(f"Not enough test data for patient {single_pid}. Need >= {window_len}, have {len(pidx)}.")
# else:
#     # last `window_len` chronological points for this patient
#     idx_last = pidx[-window_len:]
#     minutes = np.arange(window_len)


#     plt.figure(figsize=(14, 5))
#     plt.plot(minutes, y_test[idx_last], label='True Glucose')
#     for name, yhat in preds.items():
#         plt.plot(minutes, yhat[idx_last], label=name, marker='o')
#     plt.xlabel("Minute")
#     plt.ylabel("Glucose")
#     plt.title(f"Patient {single_pid}: Next {window_len} min Glucose — {'Tuned' if use_tuned else 'Baseline'} Models")
#     plt.legend()
#     plt.grid(True)
#     plt.tight_layout()
#     plt.show()


#     # --- R² scores for this patient over all their test points ---
#     print(f"Patient {single_pid} R² Scores (over all test points for this patient):")
#     for name, yhat in preds.items():
#         r2 = r2_score(y_test[pidx], yhat[pidx])
#         print(f" {name}: {r2:.3f}")

# %% [markdown]
# # 26- Baseline vs Tuned — R² / RMSE / MSE (LSTM • GRU • CNN)

# %%
def plot_baseline_vs_tuned_metrics(baseline, tuned, title="Baseline vs Tuned — Regression Metrics", show_mae=False):
    import numpy as np
    import matplotlib.pyplot as plt

    models  = ["LSTM", "GRU", "CNN"]
    metrics = ["R2", "RMSE", "MSE"] + (["MAE"] if show_mae else [])

    # Make safe copies & ensure MSE present
    base = {m: dict(baseline[m]) for m in models}
    tune = {m: dict(tuned[m])   for m in models}
    for d in (base, tune):
        for m in models:
            if "MSE" not in d[m]:
                d[m]["MSE"] = float(d[m]["RMSE"]) ** 2

    base_col, tune_col = "#3B82F6", "#EF4444"
    fig, axes = plt.subplots(1, len(metrics), figsize=(6*len(metrics), 5))
    if not isinstance(axes, (list, np.ndarray)): axes = [axes]
    fig.suptitle(title, fontsize=18, fontweight="bold")

    x = np.arange(len(models)); width = 0.36

    def _annot(ax, rects, vals, fmt="{:.3f}"):
        for r, v in zip(rects, vals):
            ax.text(r.get_x() + r.get_width()/2., r.get_height(), fmt.format(v),
                    ha='center', va='bottom', fontsize=10, fontweight='bold')

    for ax, metric in zip(axes, metrics):
        base_vals = [base[m][metric] for m in models]
        tune_vals = [tune[m][metric] for m in models]

        r1 = ax.bar(x - width/2, base_vals, width, label="Baseline", color=base_col, alpha=0.9)
        r2 = ax.bar(x + width/2, tune_vals, width, label="Tuned",    color=tune_col, alpha=0.9)

        ax.set_title(metric, fontsize=14, fontweight="bold", pad=10)
        ax.set_xticks(x, models)
        for t in ax.get_xticklabels(): t.set_fontweight('bold'); t.set_fontsize(12)
        ax.set_ylabel(metric, fontsize=12, fontweight='bold')
        ax.grid(True, axis='y', alpha=0.2)
        ax.tick_params(axis='y', labelsize=11, width=1.2)
        for t in ax.get_yticklabels(): t.set_fontweight('bold')

        fmt = "{:.3f}" if metric != "MSE" else "{:.1f}"
        _annot(ax, r1, base_vals, fmt); _annot(ax, r2, tune_vals, fmt)
        if metric == "R2": ax.set_ylim(0, 1.05)

        leg = ax.legend(frameon=True, fontsize=11)
        for txt in leg.get_texts(): txt.set_fontweight("bold")
        for s in ax.spines.values(): s.set_linewidth(1.2); s.set_color("#9CA3AF")

    plt.tight_layout(rect=[0, 0, 1, 0.92]); plt.show()

# %%
plot_baseline_vs_tuned_metrics(baseline, tuned,
    title="Baseline vs Tuned — R² / RMSE / MSE (LSTM • GRU • CNN)",
    show_mae=False  # set True if you also want a MAE panel
)

# %% [markdown]
# 27 — Per‑Patient 60‑Minute Plot + R² (Baseline or Tuned)

# %%
# --- CONFIGURE ---
single_pid = 123   # <--- change to your patient id
window_len = 60   # last N test points for this patient

# (Optional) consistent colors per model
_model_colors = {"LSTM": "#16A34A", "GRU": "#2563EB", "CNN": "#F59E0B"}

# --- SAFETY CHECKS (optional but helpful) ---
assert 'ids_test' in globals() and 'y_test' in globals(), "Run earlier cells to create ids_test and y_test."
for name in ['yp_l', 'yp_g', 'yp_c', 'yp_l_t', 'yp_g_t', 'yp_c_t', 'yt', 'yt_t']:
    assert name in globals(), f"Missing variable: {name}. Train baseline/tuned and evaluate first."

# --- SELECT INDICES FOR THIS PATIENT ---
pidx = np.where(ids_test == single_pid)[0]
if len(pidx) < window_len:
    print(f"Not enough test data for patient {single_pid}. Need >= {window_len}, have {len(pidx)}.")
else:
    idx_last = pidx[-window_len:]
    minutes  = np.arange(window_len)

    # Plot baseline and tuned side by side
    fig, axes = plt.subplots(1, 2, figsize=(18, 5), sharey=True)
    fig.suptitle(f"Patient {single_pid}: Baseline vs Tuned Models",
                 fontweight='bold', fontsize=14)

    panels = [
        ("Baseline", {"LSTM": yp_l,  "GRU": yp_g,  "CNN": yp_c},  yt),
        ("Tuned",    {"LSTM": yp_l_t,"GRU": yp_g_t,"CNN": yp_c_t}, yt_t),
    ]

    for ax, (label, preds, y_true_global) in zip(axes, panels):
        # True line
        ax.plot(minutes, y_test[idx_last], label='True Glucose', color='black', linewidth=2)

        # Model lines + R² in legend (bolded later)
        for name, yhat in preds.items():
            # R² for this patient using ALL their test points
            r2_local = r2_score(y_test[pidx], yhat[pidx]) if len(pidx) > 1 else float('nan')
            ax.plot(
                minutes, yhat[idx_last],
                label=f"{name} ({label})  R²={r2_local:.3f}",
                marker='o', linewidth=1.6, markersize=4,
                color=_model_colors.get(name, None)
            )

        # Axes styling (bold)
        ax.set_title(f"Patient {single_pid}: Next {window_len} min — {label}", fontweight='bold')
        ax.set_xlabel("Minute", fontsize=12, fontweight='bold')
        ax.grid(True, alpha=0.25)
        ax.tick_params(axis='both', labelsize=11, width=1.2)
        for t in ax.get_xticklabels() + ax.get_yticklabels():
            t.set_fontweight('bold')

        # Legend (bold)
        leg = ax.legend(frameon=True, fontsize=11, loc="lower left", ncols=1)
        for txt in leg.get_texts():
            txt.set_fontweight("bold")
        if leg.get_title() is not None:
            leg.get_title().set_fontweight("bold")
        leg.get_frame().set_linewidth(1.0)

        # Subtle spines
        for s in ax.spines.values():
            s.set_linewidth(1.1); s.set_color("#9CA3AF")

    # Bold y-label on the left subplot
    axes[0].set_ylabel("Glucose", fontsize=12, fontweight="bold")

    # Layout
    plt.tight_layout(rect=[0, 0, 1, 0.94])
    plt.show()

    # --- R² scores for this patient (baseline & tuned) ---
    print(f"Patient {single_pid} R² Scores (all test points for this patient):")
    for label, preds, _ in panels:   # <-- unpack 3 values here
        print(f"  -- {label} --")
        for name, yhat in preds.items():
            r2_local = r2_score(y_test[pidx], yhat[pidx]) if len(pidx) > 1 else float('nan')
            print(f"    {name} ({label}): {r2_local:.3f}")
# Out:
# Patient 123 R² Scores (all test points for this patient):
#   -- Baseline --
#     LSTM (Baseline): 0.932
#     GRU (Baseline): 0.919
#     CNN (Baseline): 0.965
#   -- Tuned --
#     LSTM (Tuned): 0.967
#     GRU (Tuned): 0.963
#     CNN (Tuned): 0.970
